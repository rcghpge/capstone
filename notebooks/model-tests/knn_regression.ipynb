# %% [markdown]
# ### KNN Regression Model with RF + RFECV Feature Selection

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# /home/rc/capstone/notebooks/model-tests

# %%
change_cwd = os.chdir("../../models")
# !pwd
# Out:
# /home/rc/capstone/models

# %%
# !python knn_regression.py \
--data ../data/Key_indicator_districtwise.csv \
--target Infant_Mortality_Rate_Imr_Total_Person \
--id-cols State_Name State_District_Name \
--correlation 70 --test-size 0.17 --random-state 42 --outdir ../notebooks/model-tests/knn-test-4
# Out:
# KNN Regression Model
# ======================================================================
# 📊 Dataset: (284, 644)
# 🎯 Target: 'Infant_Mortality_Rate_Imr_Total_Person' → 'Infant_Mortality_Rate_Imr_Total_Person'
# 🧹 Deduplicating: 284 → 284 samples
#
# ================================================================================
# 📈 Raw Dataset Summary
# ================================================================================
# 📊 Dataset Shape: (284, 644)
# 🎯 Target Column: 'Infant_Mortality_Rate_Imr_Total_Person'
# 🔍 Total Missing Null/NaN Values: 9,297 (5.08%)
# 🎯 Target Missing: 0/284 (0.0%)
#
# 📋 Top 10 Features with Missing Null/NaN Values:
# ------------------------------------------------------------
#   Total_Fertility_Rate_Urban               |    284 (100.0%)
#   Total_Fertility_Rate_Rural               |    284 (100.0%)
#   Post_Neo_Natal_Mortality_Rate_Urban      |     93 ( 32.7%)
#   Under_Five_Mortality_Rate_U5MR_Urban_Female |     92 ( 32.4%)
#   Under_Five_Mortality_Rate_U5MR_Urban_Male |     92 ( 32.4%)
#   Neo_Natal_Mortality_Rate_Urban           |     92 ( 32.4%)
#   Infant_Mortality_Rate_Imr_Urban_Female   |     92 ( 32.4%)
#   Infant_Mortality_Rate_Imr_Urban_Person   |     92 ( 32.4%)
#   Under_Five_Mortality_Rate_U5MR_Urban_Person |     92 ( 32.4%)
#   Infant_Mortality_Rate_Imr_Urban_Male     |     92 ( 32.4%)
#
# 📊 Total features with missing values: 199/643
#
# 🔧 Data Types:
# float64         | 614 columns
# int64           |  28 columns
# object          |   2 columns
# ================================================================================
# ✅ Raw dataset for preprocessing ((284, 644))
# 🗺️ State Column: State_Name
# ✓ statewise_histogram.png
# ✓ statewise_facets.png
# ✓ Dropped 447/639 features (70.00%) by |corr| with target; 192 remain.
# ✅ Features: 192 | Target Range: 19.2-97.0
#
# ================================================================================
# 📈 Pre-RFECV Feature Selection Summary (Post-Preprocessing + Feature Correlation Drop)
# ================================================================================
# 📊 Processed Dataset: (235, 192)
# 🎯 Target Samples: 235
# 📋 Feature Name Count: 192
# 🔍 Post-Preprocessing Missing Null/NaN Values: 0 (0.00%)
# ✅ No missing Null/NaN values after preprocessing!
# 🎯 Target Missing Null/NaN Values: 0/235 (0.0%)
#
# 🔧 Feature Breakdown:
#   📊 Numerical Features: 92/192
#   🅰️ Categorical (Post-OHE): 100
#   🔄 OHE Features Generated: 2
#
# 📊 Top 5 |corr| Features With Target Variable:
# ------------------------------------------------------------
# Infant_Mortality_Rate_Total_Upper_Limit  | 0.9863
# Infant_Mortality_Rate_Total_Lower_Limit  | 0.9753
# Infant_Mortality_Rate_Imr_Total_Male     | 0.9722
# Infant_Mortality_Rate_Imr_Rural_Person   | 0.9701
# Infant_Mortality_Rate_Imr_Total_Female   | 0.9681
# ================================================================================
# 🔍 RFECV Feature Selector:
# 🔍 Running a pass on the data..
# 🔍 X_train Shape: (235, 641)
# 🔍 X_train_processed Shape: (235, 192)
# 🔍 First 5 Original Features: ['Sample_Units_Total', 'Sample_Units_Rural', 'Sample_Units_Urban', 'Households_Total', 'Households_Rural']
# ✅ RFECV Input: 192 features
# ✅ Original Numeric Columns: 641 features
# ✅ RFECV: 192 → 12 features selected
# ✅ RFECV Feature Selection Complete! 0.2m total
# ✓ metrics.csv
#
# 📊 Generating model inference plots...
# ✓ train_residuals.png
# ✓ test_residuals.png
# ✓ training_residuals_granularity.png
# ✓ testing_residuals_granularity.png
# ✓ feature_target_correlations.png
# ✓ train_scatter.png
# ✓ test_scatter.png
# ✓ train_residuals.png
# ✓ test_residuals.png
# ✓ feature_importance.png
# ✓ train_distribution.png
# ✓ test_distribution.png
# ✓ model_comparison.png
#
# 📊 Generating model learning curve...
# ✓ learning_curve.png saved
# ✓ Final CV R²: 0.9882 ± 0.0022
# ✓ Final Train R²: 1.0000 ± 0.0000
#
# 🔍 Train Outlier Analysis
# --------------------------------------------------------------------------------
# 📊 Statistical Outliers (IQR 1.5):   0/235 ( 0.0%)
#
# 🚨 Top 5 KNN Regression Model Inference Worst Predictions (Residuals Errors):
# #   | State           | District             | True   | Pred   | Error
# --------------------------------------------------------------------------------
#  1  | Madhya Pradesh  | Datia                |   73.3 |   73.3 |    0.0
#  2  | Uttar Pradesh   | Varanasi             |   71.6 |   71.6 |    0.0
#  3  | Madhya Pradesh  | East Nimar           |   66.7 |   66.7 |    0.0
#  4  | Chhattisgarh    | Mahasamund           |   57.2 |   57.2 |    0.0
#  5  | Rajasthan       | Jhalawar             |   63.0 |   63.0 |    0.0
# 💾 Saved: train_outliers_summary.csv
#
# 🔍 Test Outlier Analysis
# --------------------------------------------------------------------------------
# 📊 Statistical Outliers (IQR 1.5):   1/ 49 ( 2.0%)
#
# 🚨 Top 5 KNN Regression Model Inference Worst Predictions (Residuals Errors):
# #   | State           | District             | True   | Pred   | Error
# --------------------------------------------------------------------------------
#  1  | Odisha          | Balangir             |   97.0 |   89.2 |    7.8
#  2  | Bihar           | Jamui                |   51.0 |   48.5 |    2.5
#  3  | Madhya Pradesh  | Shivpuri             |   68.9 |   66.4 |    2.5
#  4  | Assam           | Hailakandi           |   52.0 |   54.5 |    2.5
#  5  | Jharkhand       | Pashchimi Singhbhum  |   53.0 |   55.1 |    2.1
# 💾 Saved: test_outliers_summary.csv
#
# ======================================================================
# ✅ KNN Model Results:
# ======================================================================
# 🎯 Test: R²=0.9887 | Adj R²=0.9849 | RMSE=1.6523 | MAE=1.1209
# 📊 Features: 12/192
# 📁 Outputs: ../notebooks/model-tests/knn-test-4
# ======================================================================
