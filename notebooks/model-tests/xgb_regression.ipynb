# %% [markdown]
# ### XGBoost Regression Model with RF + RFECV Feature Selection

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# /home/rc/capstone/notebooks/model-tests

# %%
change_cwd = os.chdir("../../models")
# !pwd
# Out:
# /home/rc/capstone/models

# %%
# !python xgb_regression.py \
--data ../data/Key_indicator_districtwise.csv \
--target "Infant_Mortality_Rate_Imr_Total_Person" \
--id-cols "State_Name" "State_District_Name" \
--correlation 35 --test-size 0.15 --random-state 42 \
--n-estimators 800 --learning-rate 0.5 --max-depth 3 \
--reg-lambda 4 --reg-alpha 2 --min-child-weight 7 --outdir ../notebooks/model-tests/xgb-test-4
# Out:
# XGBoost Regression Model
# ======================================================================
# 📊 Dataset: (284, 644)
# 🎯 Target: Infant_Mortality_Rate_Imr_Total_Person -> Infant_Mortality_Rate_Imr_Total_Person
# 🧹 Deduplicating: 284 -> 284 samples
#
# ================================================================================
# 📈 Raw Dataset Summary
# ================================================================================
# 📊 Dataset Shape: 284 samples, 644 features
# 🎯 Target Column: Infant_Mortality_Rate_Imr_Total_Person
# 🔍 Total Missing Null/NaN Values: 9,297 (5.08%)
# 🎯 Target Missing: 0/284 (0.0%)
#
# 📋 Top 10 Features with Missing Null/NaN Values
# ------------------------------------------------------------
# Total_Fertility_Rate_Urban               |    284 (100.0%)
# Total_Fertility_Rate_Rural               |    284 (100.0%)
# Post_Neo_Natal_Mortality_Rate_Urban      |     93 ( 32.7%)
# Under_Five_Mortality_Rate_U5mr_Urban_Female |     92 ( 32.4%)
# Under_Five_Mortality_Rate_U5mr_Urban_Male |     92 ( 32.4%)
# Neo_Natal_Mortality_Rate_Urban           |     92 ( 32.4%)
# Infant_Mortality_Rate_Imr_Urban_Female   |     92 ( 32.4%)
# Infant_Mortality_Rate_Imr_Urban_Person   |     92 ( 32.4%)
# Under_Five_Mortality_Rate_U5mr_Urban_Person |     92 ( 32.4%)
# Infant_Mortality_Rate_Imr_Urban_Male     |     92 ( 32.4%)
#
# 📊 Total features with missing values: 199/643
#
# 🔧 Data Types:
#   float64    | 614 columns
#   int64      |  28 columns
#   object     |   2 columns
# ================================================================================
# ✅ Raw dataset for preprocessing ((284, 644))
# 🗺️ State Column: State_Name
# ✓ statewise_histogram.png
# ✓ statewise_facets.png
#
# 🔧 Building preprocessor...
#   ✓ Dropped 224/639 features (35.00%) by |corr| with target; 415 remain.
#   ✓ Features: 415 | Target Range: 19.2-97.0
#
# ================================================================================
# 📈 Pre-RFECV Feature Selection Summary (Post-Preprocessing + Feature Correlation Drop)
# ================================================================================
# 📊 Processed Dataset: 241 samples, 415 features
# 🎯 Target Samples: 241
# 📋 Feature Name Count: 415
# 🔍 Post-Preprocessing Missing Null/NaN Values: 0 (0.00%)
# ✅ No missing Null/NaN values after preprocessing!
# 🎯 Target Missing Null/NaN Values: 0/241 (0.0%)
#
# 🔧 Feature Breakdown:
#   📊 Numerical Features: 201/415
#   🅰️ Categorical (Post-OHE): 214
#   🔄 OHE Features Generated: 3
#
# 📊 Top 5 |corr| Features With Target Variable
# ------------------------------------------------------------
# Children_Attended_Before_Drop_Out_Age_6_ | 0.2229
# Children_Currently_Attending_School_Age_ | 0.2216
# Currently_Married_Pregnant_Women_Aged_15 | 0.2213
# Average_Month_By_Which_Children_Received | 0.2213
# Delivery_At_Private_Institution_Urban    | 0.2212
# ================================================================================
# 🔍 RFECV Feature Selector
# 🔍 Running a pass on the data..
#
# ✅ RFECV Feature Selection Complete! 0.2m total
# ✅ RFECV Input: 415 features
# ✅ RFECV Selected: 10 features (2.4%)
# ✅ Features: 10/415
# ✅ RFECV Ranking score: 1.000
#
# 📊 Training XGBoost Model...
# ✓ RFECV selected 106 features (pre-cap)
# ✓ RFECV rank 1 indices: [ 2  3  5  7 12 17 40 51 52 56]
# ✓ metrics.csv
#
# 📊 Generating model inference plots...
# ✓ train_residuals.png
# ✓ test_residuals.png
# ✓ feature_importance.png
# ✓ train_scatter.png
# ✓ test_scatter.png
#
# 📊 Generating model learning curve...
# ✓ Check 5‑fold CV R²: 0.0091 ± 0.1894
# ✓ learning_curve.png
# ✓ Final CV R²: 0.0421 ± 0.1931
# ✓ Final Train R²: 0.9999 ± 0.0000
#
# 🔍 Train Outlier Analysis
# --------------------------------------------------------------------------------
# 📊 Statistical Outliers (IQR ±1.5):   7/241 ( 2.9%)
#
# 🚨 Top 5 XGBoost Regression Model Inference Worst Predictions (Residuals Errors)
#   # | State      | District   |   True |   Pred |  Error
# --------------------------------------------------------------------------------
#            1 Jharkhand       Kodarma                27.0   38.9   11.9
#            2 Bihar           Vaishali               40.0   50.9   10.9
#            3 Uttarakhand     Rudraprayag            19.2   30.0   10.8
#            4 Jharkhand       Purbi Singhbhum        25.0   35.3   10.3
#            5 Uttar Pradesh   Chitrakoot             67.3   58.1    9.2
# 💾 Saved: train_outliers_summary.csv
# ================================================================================
#
# 🔍 Test Outlier Analysis
# --------------------------------------------------------------------------------
# 📊 Statistical Outliers (IQR ±1.5):   1/ 43 ( 2.3%)
#
# 🚨 Top 5 XGBoost Regression Model Inference Worst Predictions (Residuals Errors)
#   # | State      | District   |   True |   Pred |  Error
# --------------------------------------------------------------------------------
#            1 Odisha          Balangir               97.0   62.0   35.0
#            2 Uttar Pradesh   Sitapur                80.2   49.7   30.5
#            3 Odisha          Kandhamal              82.0   54.6   27.4
#            4 Bihar           Darbhanga              44.0   66.6   22.6
#            5 Odisha          Sundargarh             47.0   65.1   18.1
# 💾 Saved: test_outliers_summary.csv
# ================================================================================
#
# ======================================================================
# ✅ XGBoost Model Results
# ======================================================================
# 🎯 Test: R²=0.3570 | Adj R²=0.1561 | RMSE=12.5945 | MAE=9.8813
# 📊 Features: 10/415
# 📁 Outputs: ../notebooks/model-tests/xgb-test-4
# ======================================================================
