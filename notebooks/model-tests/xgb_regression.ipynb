# %% [markdown]
# ### XGBoost Regression Model with RF + RFECV Feature Selection

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# /home/rc/capstone/notebooks/model-tests

# %%
change_cwd = os.chdir("../../models")
# !pwd
# Out:
# /home/rc/capstone/models

# %%
# !python xgb_regression.py \
--data ../data/Key_indicator_districtwise.csv \
--target "Infant_Mortality_Rate_Imr_Total_Person" \
--id-cols "State_Name" "State_District_Name" \
--correlation 30 --test-size 0.15 --random-state 42 \
--n-estimators 800 --learning-rate 0.05 --max-depth 3 \
--reg-lambda 5 --min-child-weight 5 --outdir ../notebooks/model-tests/xgb-test-1
# Out:
# XGBoost Regression Model
# ======================================================================
# Dataset: (284, 644)
# Target: Infant_Mortality_Rate_Imr_Total_Person -> yy_Infant_Mortality_Rate_Imr_Total_Person
# Deduplicating: 284 -> 284 samples
# ================================================================================
# Raw Dataset Summary
# ================================================================================
# Dataset Shape: 284 samples, 644 features
# Target Column: yy_Infant_Mortality_Rate_Imr_Total_Person
# Total Missing (Null/NaN) Values: 9,297 (5.08%)
# Target Missing: 0/284 (0.0%)
# ------------------------------------------------------------
# Top 10 Features with Missing (Null/NaN) Values
# ll_Total_Fertility_Rate_Urban               284 (100.0%)
# ll_Total_Fertility_Rate_Rural               284 (100.0%)
# yy_Post_Neo_Natal_Mortality_Rate_Urban       93 ( 32.7%)
# yy_Under_Five_Mortality_Rate_U5mr_Urban_Female     92 ( 32.4%)
# yy_Under_Five_Mortality_Rate_U5mr_Urban_Male     92 ( 32.4%)
# yy_Neo_Natal_Mortality_Rate_Urban            92 ( 32.4%)
# yy_Infant_Mortality_Rate_Imr_Urban_Female     92 ( 32.4%)
# yy_Infant_Mortality_Rate_Imr_Urban_Person     92 ( 32.4%)
# yy_Under_Five_Mortality_Rate_U5mr_Urban_Person     92 ( 32.4%)
# yy_Infant_Mortality_Rate_Imr_Urban_Male      92 ( 32.4%)
# Total features with missing values: 199/643
# Data Types
# float64         614 columns
# int64            28 columns
# object            2 columns
# ================================================================================
# After target cleanup: (284, 644)
# State Column: State_Name
# Building preprocessor...
# Dropped 192/639 features (30.00%) by corr with target (447 remain).
# Features: 447 | Target Range: 19.2-97.0
# ================================================================================
# Pre-RFECV Feature Selection Summary (Post-Preprocessing + Feature Correlation Drop)
# ================================================================================
# Processed Dataset: 241 samples, 447 features
# Target Samples: 241
# Feature Name Count: 447
# Post-Preprocessing Missing (Null/NaN) Values: 0 (0.00%)
# No missing (Null/NaN) values after preprocessing!
# Target Missing (Null/NaN) Values: 0/241 (0.0%)
# Feature Breakdown
#   Numerical Features: 219/447
#   Categorical (Post-OHE): 228
#   OHE Features Generated: 4
# Top 5 corr Features With Target Variable
#   mm_Women_Who_Received_Any_Anc_Before_Abo 0.2431
#   vv_Children_Breastfed_Within_One_Hour_Of 0.2423
#   ll_Mean_Number_Of_Children_Surviving_To_ 0.2410
#   ff_Children_Currently_Attending_School_A 0.2402
#   kk_Having_Diagnosed_For_Chronic_Illness_ 0.2398
# ================================================================================
# RFECV Feature Selector
# Running a pass on the data..
#
# RFECV Feature Selection Complete! 14.5m total
# RFECV Input: 447 features
# RFECV Selected (after cap): 10 features (2.2%)
# Features  : 10/447
# RFECV Ranking score: 1.000
#
# Training XGBoost Model...
# metrics.csv
#
# Generating model inference plots...
# train_residuals.png
# test_residuals.png
# feature_importance.png
# train_scatter.png
# test_scatter.png
#
# Generating model learning curve...
# learning_curve.png saved
# Final CV R²: 0.4181 ± 0.0462
# Final Train R²: 0.9959 ± 0.0003
# Train Outlier Analysis
# --------------------------------------------------------------------------------
# Statistical Outliers (IQR ±1.5):   4/241 ( 1.7%)
# Top 5 XGBoost Regression Model Inference Worst Predictions (Residuals/Errors)
#   # State           District               True   Pred  Error
# --------------------------------------------------------------------------------
#            1 Jharkhand       Garhwa                 33.0   51.2   18.2
#            2 Chhattisgarh    Bilaspur               38.4   55.2   16.8
#            3 Uttar Pradesh   Hardoi                 81.3   65.3   16.0
#            4 Jharkhand       Hazaribagh             29.0   43.8   14.8
#            5 Uttar Pradesh   Saharanpur             76.4   62.1   14.3
# Saved train_outliers_summary.csv
# ================================================================================
# Test Outlier Analysis
# --------------------------------------------------------------------------------
# Statistical Outliers (IQR ±1.5):   3/ 43 ( 7.0%)
# Top 5 XGBoost Regression Model Inference Worst Predictions (Residuals/Errors)
#   # State           District               True   Pred  Error
# --------------------------------------------------------------------------------
#            1 Odisha          Balangir               97.0   51.2   45.8
#            2 Odisha          Kandhamal              82.0   51.4   30.6
#            3 Jharkhand       Dhanbad                26.0   51.0   25.0
#            4 Chhattisgarh    Bastar                 39.6   60.2   20.6
#            5 Uttar Pradesh   Gonda                  71.2   50.7   20.6
# Saved test_outliers_summary.csv
# ================================================================================
# ======================================================================
# XGBoost Model Results
# ======================================================================
# Test R²   : 0.3407
# Adj R²    : 0.1347
# RMSE      : 12.7533
# MAE       : 9.0019
# Features  : 24/447
# Outputs   : ../notebooks/model-tests/xgb-test-1
# ======================================================================
