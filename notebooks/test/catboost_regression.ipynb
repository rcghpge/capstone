# %% [markdown]
# ### CatBoost Regression Model

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# /home/rc/Academia/UTA/data4382/capstone/notebooks/model-tests

# %%
change_cwd = os.chdir("../../models")
# !pwd
# Out:
# /home/rc/Academia/UTA/data4382/capstone/models

# %%
# !python catboost_regression.py \
--data ../data/Key_indicator_districtwise.csv --target "Infant_Mortality_Rate_Imr_Total_Person" \
--id-cols "State_Name" "State_District_Name" --cv-folds 7 --correlation 75 --test-size 0.20 --random-state 42 \
--iterations 10000 --depth 3 --learning-rate 0.01 --l2-leaf-reg 50 --min-child-weight 75 --early-stopping-rounds 5000 \
--top-n-plot 10 --chunk-size 50000 --out_dir ../notebooks/model-tests/catboost-test
# Out:
# ======================================================================
# CatBoost Regression Model
# ======================================================================
# Dataset: (284, 644)
# Target: Infant_Mortality_Rate_Imr_Total_Person -> Infant_Mortality_Rate_Imr_Total_Person
#
# ================================================================================
# 📈 Raw Dataset Summary
# ================================================================================
# 📊 Dataset Shape: 284 samples, 644 features
# 🎯 Target Column: Infant_Mortality_Rate_Imr_Total_Person
# 🔍 Total Missing Null/NaN Values: 9,297 (5.08%)
# 🎯 Target Missing: 0/284 (0.0%)
#
# 📋 Top 10 Features with Missing Null/NaN Values
# ------------------------------------------------------------
# Total_Fertility_Rate_Urban               |    284 (100.0%)
# Total_Fertility_Rate_Rural               |    284 (100.0%)
# Post_Neo_Natal_Mortality_Rate_Urban      |     93 ( 32.7%)
# Under_Five_Mortality_Rate_U5mr_Urban_Female |     92 ( 32.4%)
# Under_Five_Mortality_Rate_U5mr_Urban_Male |     92 ( 32.4%)
# Neo_Natal_Mortality_Rate_Urban           |     92 ( 32.4%)
# Infant_Mortality_Rate_Imr_Urban_Female   |     92 ( 32.4%)
# Infant_Mortality_Rate_Imr_Urban_Person   |     92 ( 32.4%)
# Under_Five_Mortality_Rate_U5mr_Urban_Person |     92 ( 32.4%)
# Infant_Mortality_Rate_Imr_Urban_Male     |     92 ( 32.4%)
#
# 📊 Total features with missing values: 199/643
#
# 🔧 Data Types:
# ℹ️ float64    | 614 columns
# ℹ️ int64      |  28 columns
# ℹ️ object     |   2 columns
# ================================================================================
# State Column: State_Name
# ✓ statewise_histogram.png
# ✓ statewise_facets.png
# Building preprocessor...
# ✓ Dropped 479/639 features (75.00%) by |corr| with target; 160 remain.
# Features after corr drop: 160
# RFECV Feature Selector
# RFECV Selected 128 features (80.0%)
# Training CatBoost Regression Model...
# ✓ metrics.csv
# ------------------------------------------------------------
#            R2   AdjR2     RMSE     MAE
# Split
# Train  0.9697  0.9301   2.3578  1.9048
# Test   0.4370     NaN  11.9735  9.3620
# Generating plots...
# ✓ train_residuals.png
# ✓ test_residuals.png
# ✓ train_scatter.png
# ✓ test_scatter.png
# ✓ feature_importance.png
# ✓ feature_target_correlations.png
# ✓ model_input_feature_target_correlations.png
# 5-fold CV R²: 0.1053 ± 0.0608
# ✓ mae_learning_curve.png
# ✓ rmse_learning_curve.png
#
# 🔍 Train Outlier Analysis
# --------------------------------------------------------------------------------
# 📊 Statistical Outliers (IQR ±1.5):   2/227 ( 0.9%)
#
# 🚨 Top 5 KNN Regression Model Inference Worst Predictions (Residuals Errors):
#  #   | State           | District             | True   | Pred   | Error
# --------------------------------------------------------------------------------
#  1  | Uttar Pradesh   | Ambedkar Nagar       |   63.2 |   69.8 |    6.7
#  2  | Jharkhand       | Purbi Singhbhum      |   25.0 |   31.7 |    6.7
#  3  | Uttar Pradesh   | Shrawasti            |   96.4 |   90.4 |    6.0
#  4  | Uttarakhand     | Rudraprayag          |   19.2 |   25.1 |    5.9
#  5  | Assam           | Darrang              |   70.0 |   64.2 |    5.8
# 💾 Saved: train_outliers_summary.csv
#
# 🔍 Test Outlier Analysis
# --------------------------------------------------------------------------------
# 📊 Statistical Outliers (IQR ±1.5):   1/ 57 ( 1.8%)
#
# 🚨 Top 5 KNN Regression Model Inference Worst Predictions (Residuals Errors):
#  #   | State           | District             | True   | Pred   | Error
# --------------------------------------------------------------------------------
#  1  | Odisha          | Balangir             |   97.0 |   54.4 |   42.6
#  2  | Odisha          | Kandhamal            |   82.0 |   52.4 |   29.6
#  3  | Uttarakhand     | Dehradun             |   34.1 |   58.9 |   24.8
#  4  | Jharkhand       | Dhanbad              |   26.0 |   47.6 |   21.6
#  5  | Uttar Pradesh   | Aligarh              |   70.0 |   52.7 |   17.3
# 💾 Saved: test_outliers_summary.csv
# ======================================================================
# CatBoost Model Results
# ======================================================================
# Test R2 0.4370 Adj R2 nan RMSE 11.9735 MAE 9.3620
# Features 128/160 Pre/Post RFECV
# Outputs ../notebooks/model-tests/lnos-arch-catboost-test
# ======================================================================
