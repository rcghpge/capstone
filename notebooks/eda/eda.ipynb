# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
import kagglehub
import pandas as pd
import tqdm 

path = kagglehub.dataset_download("rajanand/key-indicators-of-annual-health-survey")
print(f"Kaggle Health Analytics data repository:")
print("Dataset at:", path)
print("Files:", os.listdir(path))

csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]
districtwise_file = next(f for f in csv_files if 'districtwise' in f.lower())
dataset = os.path.join(path, districtwise_file)

df = pd.read_csv(dataset)
print(f"\nPrimary dataset: {districtwise_file}")
print(f"✅ Dataframe shape: {df.shape} (expected ~284 rows x 642 cols for districts)")

# %%
# !mkdir ../../data
# %ls ~/.cache/kagglehub/datasets/rajanand/key-indicators-of-annual-health-survey/versions/1

# !cp -r ~/.cache/kagglehub/datasets/rajanand/key-indicators-of-annual-health-survey/versions/1/* ../../data/

# %%
def nullcount(df):
    nullcounts={}
    for col in df:
        nullcounts[col] = df[col].isnull().sum()
    return nullcounts

# %%
df = pd.read_csv('../../data/Key_indicator_districtwise.csv')

# %%
df.shape

# %%
df.head()

# %%
states = list(df.State_Name.unique())
print(len(states))
states

# %%
df.YY_Crude_Death_Rate_Cdr_Total_Person

# %%
print(df.YY_Infant_Mortality_Rate_Imr_Total_Person.min())
print(df.YY_Infant_Mortality_Rate_Imr_Total_Person.max())

# %%
# %matplotlib inline
os.makedirs('eda-plots', exist_ok=True)

plt.figure(figsize=(11, 7)) 
plt.hist(df.YY_Infant_Mortality_Rate_Imr_Total_Person, color='steelblue', alpha=0.7, bins=9)
plt.axvline(df.YY_Infant_Mortality_Rate_Imr_Total_Person.mean(), color='lightcoral', label='Mean', alpha=0.7, lw=2)
plt.axvline(df.YY_Infant_Mortality_Rate_Imr_Total_Person.median(), color='orange', label = 'Median', alpha=0.7, linestyle='dashed', lw=2)
plt.xlabel('Infant Mortality Rate (Deaths per 1,000 live births)')
plt.ylabel('Frequency (Number of Records)')
plt.title('Infant Mortality Rate (IMR) Target Variable Distribution')
plt.legend()
plt.savefig("eda-plots/imr-histogram.png", dpi=300, bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
plt.figure(figsize=(16, 8))
plt.bar(df['State_Name'], df['YY_Infant_Mortality_Rate_Imr_Total_Person'], color='steelblue', alpha=0.7)
plt.xlabel('State Name', fontsize=12)
plt.ylabel('Infant Mortality Rate (per 1,000 live births)', fontsize=12)
plt.title('Infant Mortality Rate (IMR) by State', fontsize=14, pad=20)
plt.xticks(rotation=45, ha='right')
#plt.grid(True, alpha=0.7)
plt.tight_layout() 
plt.savefig("eda-plots/imr-by-state.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
top_districts = df.sort_values('YY_Infant_Mortality_Rate_Imr_Total_Person', ascending=False).head(10)

plt.figure(figsize=(12, 8))
plt.barh(top_districts['State_District_Name'], top_districts['YY_Infant_Mortality_Rate_Imr_Total_Person'], color='steelblue', alpha=0.7)
plt.xlabel('Infant Mortality Rate')
plt.ylabel('District Name')
plt.title('Top 10 Districts by Infant Mortality Rate')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig("eda-plots/top-10-imr-districts.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
## Target Var Nulls
df.YY_Infant_Mortality_Rate_Imr_Total_Person.isna().sum()

# %%
## Correlation overview
df.select_dtypes(include='number').corr()

# %%
# Ordered correlation with target var
target_corr = dict(df.select_dtypes(include='number').corr()['YY_Infant_Mortality_Rate_Imr_Total_Person'])
sorted(target_corr.items(), key = lambda item: item[1])

# %%
# Columns representing totals
col_totals=[]
for c in df.columns:
    if 'Total' in c:
        col_totals.append(c)
col_totals

# %%
# Distributions for variable totals
for c in col_totals:
    plt.hist(df[c], color='steelblue', alpha=0.7, bins=7), plt.title(c)
    plt.show()

# %%
## Null values for each feature with nulls
null_counts = nullcount(df)
has_null = dict()
for k,v in null_counts.items():
    if v>0:
        has_null[k]=v
sorted(has_null.items(), key = lambda item: item[1])

# %%
## Number of features with nulls
len(has_null)
