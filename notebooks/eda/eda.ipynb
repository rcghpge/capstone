# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
import kagglehub
import pandas as pd
import tqdm as tqdm


path = kagglehub.dataset_download("rajanand/key-indicators-of-annual-health-survey")
print(f"Kaggle Health Analytics data repository:")
print("Dataset at:", path)
print("Files:", os.listdir(path))  

csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]
dataset = os.path.join(path, csv_files[0]) 

df = pd.read_csv(dataset)
print(f"\nPrimary dataset: Key_indicator_districtwise.csv")
print(f"✅ Dataframe shape: {df.shape}")
# Out:
# Downloading to /home/rc/.cache/kagglehub/datasets/rajanand/key-indicators-of-annual-health-survey/1.archive...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 1.34M/1.34M [00:00<00:00, 8.58MB/s]
# Extracting files...
# Kaggle Health Analytics data repository:
# Dataset at: /home/rc/.cache/kagglehub/datasets/rajanand/key-indicators-of-annual-health-survey/versions/1
# Files: ['Key_indicator_districtwise.csv', 'Key_indicator_statewise.csv', 'Key_Indicator_State_and_District_wise_data']
#
# Primary dataset: Key_indicator_districtwise.csv
# ✅ Dataframe shape: (284, 644)

# %%
# !mkdir ../../data
# %ls ~/.cache/kagglehub/datasets/rajanand/key-indicators-of-annual-health-survey/versions/1

# !cp -r ~/.cache/kagglehub/datasets/rajanand/key-indicators-of-annual-health-survey/versions/1/* ../../data/
# Out:
# mkdir: ../../data: File exists
# Key_Indicator_State_and_District_wise_data/  Key_indicator_statewise.csv
# Key_indicator_districtwise.csv

# %%
def nullcount(df):
    nullcounts={}
    for col in df:
        nullcounts[col] = df[col].isnull().sum()
    return nullcounts

# %%
df = pd.read_csv('../../data/Key_indicator_districtwise.csv')

# %%
df.shape
# Out:
# (284, 644)

# %%
df.head()
# Out:
#   State_Name State_District_Name  AA_Sample_Units_Total  \
# 0      Assam             Barpeta                     53
# 1      Assam          Bongaigaon                     89
# 2      Assam              Cachar                    105
# 3      Assam             Darrang                     26
# 4      Assam             Dhemaji                    121
#
#    AA_Sample_Units_Rural  AA_Sample_Units_Urban  AA_Households_Total  \
# 0                     47                      6                13711
# 1                     73                     16                17384
# 2                     84                     21                27488
# 3                     24                      2                 5951
# 4                    108                     13                14481
#
#    AA_Households_Rural  AA_Households_Urban  AA_Population_Total  \
# 0                12765                  946                64606
# 1                14904                 2480                84012
# 2                24207                 3281               127158
# 3                 5769                  182                29048
# 4                12619                 1862                75451
#
#    AA_Population_Rural  ...  \
# 0                60293  ...
# 1                73899  ...
# 2               112171  ...
# 3                28256  ...
# 4                66537  ...
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit  \
# 0                                                 54
# 1                                                 58
# 2                                                 68
# 3                                                 79
# 4                                                 40
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit  \
# 0                                                 70
# 1                                                 73
# 2                                                 80
# 3                                                107
# 4                                                 53
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit  \
# 0                                                NaN
# 1                                                NaN
# 2                                               31.0
# 3                                                NaN
# 4                                               11.0
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit  \
# 0                                                NaN
# 1                                                NaN
# 2                                               57.0
# 3                                                NaN
# 4                                               38.0
#
#    ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit  \
# 0                                      871
# 1                                      897
# 2                                      891
# 3                                      913
# 4                                      935
#
#    ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit  \
# 0                                      985
# 1                                     1005
# 2                                      966
# 3                                     1102
# 4                                     1045
#
#    ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit  \
# 0                                      851
# 1                                      911
# 2                                      871
# 3                                      908
# 4                                      938
#
#    ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit  \
# 0                                      965
# 1                                     1026
# 2                                      949
# 3                                     1097
# 4                                     1054
#
#    ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit  \
# 0                                    908.0
# 1                                    621.0
# 2                                    905.0
# 3                                      NaN
# 4                                    772.0
#
#    ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit
# 0                                   1611.0
# 1                                    956.0
# 2                                   1168.0
# 3                                      NaN
# 4                                   1083.0
#
# [5 rows x 644 columns]

# %%
states = list(df.State_Name.unique())
print(len(states))
states
# Out:
# 9
# ['Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Jharkhand',
#  'Madhya Pradesh',
#  'Odisha',
#  'Rajasthan',
#  'Uttar Pradesh',
#  'Uttarakhand']

# %%
df.YY_Crude_Death_Rate_Cdr_Total_Person
# Out:
# 0      6.60
# 1      6.10
# 2      7.30
# 3      8.10
# 4      4.50
#        ...
# 279    6.16
# 280    6.06
# 281    8.74
# 282    5.30
# 283    4.63
# Name: YY_Crude_Death_Rate_Cdr_Total_Person, Length: 284, dtype: float64

# %%
 ## Range of the target variable
print(df.YY_Infant_Mortality_Rate_Imr_Total_Person.min())
print(df.YY_Infant_Mortality_Rate_Imr_Total_Person.max())
# Out:
# 19.22
# 97.0

# %%
## Target Variable Distribution
plt.hist(df.YY_Infant_Mortality_Rate_Imr_Total_Person, bins=20)
plt.axvline(df.YY_Infant_Mortality_Rate_Imr_Total_Person.mean(), color='red', label='Mean')
plt.axvline(df.YY_Infant_Mortality_Rate_Imr_Total_Person.median(), color='orange', label = 'Median')
plt.title('Target Variable Distribution'), plt.legend()
plt.show()

# %%
## Target Var Nulls
df.YY_Infant_Mortality_Rate_Imr_Total_Person.isna().sum()
# Out:
# np.int64(0)

# %%
## Correlation overview
df.select_dtypes(include='number').corr()
# Out:
#                                          AA_Sample_Units_Total  \
# AA_Sample_Units_Total                                 1.000000
# AA_Sample_Units_Rural                                 0.879744
# AA_Sample_Units_Urban                                 0.664112
# AA_Households_Total                                   0.915218
# AA_Households_Rural                                   0.794245
# ...                                                        ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit              -0.233965
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit               0.040244
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit              -0.211274
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit               0.228764
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit              -0.252206
#
#                                          AA_Sample_Units_Rural  \
# AA_Sample_Units_Total                                 0.879744
# AA_Sample_Units_Rural                                 1.000000
# AA_Sample_Units_Urban                                 0.228788
# AA_Households_Total                                   0.784546
# AA_Households_Rural                                   0.879880
# ...                                                        ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit              -0.161355
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit               0.115704
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit              -0.178947
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit               0.078635
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit              -0.087441
#
#                                          AA_Sample_Units_Urban  \
# AA_Sample_Units_Total                                 0.664112
# AA_Sample_Units_Rural                                 0.228788
# AA_Sample_Units_Urban                                 1.000000
# AA_Households_Total                                   0.640218
# AA_Households_Rural                                   0.242616
# ...                                                        ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit              -0.225313
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit              -0.099542
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit              -0.151190
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit               0.340372
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit              -0.374116
#
#                                          AA_Households_Total  \
# AA_Sample_Units_Total                               0.915218
# AA_Sample_Units_Rural                               0.784546
# AA_Sample_Units_Urban                               0.640218
# AA_Households_Total                                 1.000000
# AA_Households_Rural                                 0.889939
# ...                                                      ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit            -0.221557
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit             0.141646
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit            -0.208497
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit             0.270664
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit            -0.200014
#
#                                          AA_Households_Rural  \
# AA_Sample_Units_Total                               0.794245
# AA_Sample_Units_Rural                               0.879880
# AA_Sample_Units_Urban                               0.242616
# AA_Households_Total                                 0.889939
# AA_Households_Rural                                 1.000000
# ...                                                      ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit            -0.156330
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit             0.237102
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit            -0.188050
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit             0.131485
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit            -0.025769
#
#                                          AA_Households_Urban  \
# AA_Sample_Units_Total                               0.613484
# AA_Sample_Units_Rural                               0.187966
# AA_Sample_Units_Urban                               0.960531
# AA_Households_Total                                 0.632763
# AA_Households_Rural                                 0.209956
# ...                                                      ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit            -0.209536
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit            -0.098910
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit            -0.127684
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit             0.354504
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit            -0.379968
#
#                                          AA_Population_Total  \
# AA_Sample_Units_Total                               0.872806
# AA_Sample_Units_Rural                               0.741014
# AA_Sample_Units_Urban                               0.621832
# AA_Households_Total                                 0.975385
# AA_Households_Rural                                 0.877945
# ...                                                      ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit            -0.218823
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit             0.186992
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit            -0.203252
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit             0.274554
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit            -0.200846
#
#                                          AA_Population_Rural  \
# AA_Sample_Units_Total                               0.737195
# AA_Sample_Units_Rural                               0.818504
# AA_Sample_Units_Urban                               0.222319
# AA_Households_Total                                 0.853393
# AA_Households_Rural                                 0.972468
# ...                                                      ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit            -0.144190
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit             0.286058
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit            -0.174845
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit             0.131205
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit            -0.020800
#
#                                          AA_Population_Urban  \
# AA_Sample_Units_Total                               0.593355
# AA_Sample_Units_Rural                               0.161093
# AA_Sample_Units_Urban                               0.961576
# AA_Households_Total                                 0.610511
# AA_Households_Rural                                 0.186031
# ...                                                      ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit            -0.221046
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit            -0.100797
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit            -0.132533
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit             0.363064
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit            -0.396697
#
#                                          AA_Ever_Married_Women_Aged_15_49_Years_Total  \
# AA_Sample_Units_Total                                                        0.894308
# AA_Sample_Units_Rural                                                        0.759552
# AA_Sample_Units_Urban                                                        0.636709
# AA_Households_Total                                                          0.983661
# AA_Households_Rural                                                          0.878744
# ...                                                                               ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                     -0.214626
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                      0.172307
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                     -0.199375
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                      0.282345
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                     -0.199123
#
#                                          ...  \
# AA_Sample_Units_Total                    ...
# AA_Sample_Units_Rural                    ...
# AA_Sample_Units_Urban                    ...
# AA_Households_Total                      ...
# AA_Households_Rural                      ...
# ...                                      ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit  ...
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit  ...
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit  ...
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit  ...
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit  ...
#
#                                          ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit  \
# AA_Sample_Units_Total                                                            -0.407542
# AA_Sample_Units_Rural                                                            -0.371923
# AA_Sample_Units_Urban                                                            -0.249597
# AA_Households_Total                                                              -0.346214
# AA_Households_Rural                                                              -0.310141
# ...                                                                                    ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                           0.098773
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                           0.002275
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                           0.067337
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                          -0.053664
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                           0.135840
#
#                                          ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit  \
# AA_Sample_Units_Total                                                            -0.475705
# AA_Sample_Units_Rural                                                            -0.460122
# AA_Sample_Units_Urban                                                            -0.250470
# AA_Households_Total                                                              -0.454737
# AA_Households_Rural                                                              -0.450367
# ...                                                                                    ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                           0.116778
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                          -0.084525
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                           0.094519
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                          -0.072759
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                           0.118918
#
#                                          ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit  \
# AA_Sample_Units_Total                                                            -0.199355
# AA_Sample_Units_Rural                                                            -0.259108
# AA_Sample_Units_Urban                                                            -0.010903
# AA_Households_Total                                                              -0.172191
# AA_Households_Rural                                                              -0.234610
# ...                                                                                    ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                          -0.011618
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                          -0.030420
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                          -0.011284
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                           0.206472
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                          -0.126536
#
#                                          ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit  \
# AA_Sample_Units_Total                                                            -0.474226
# AA_Sample_Units_Rural                                                            -0.344661
# AA_Sample_Units_Urban                                                            -0.426447
# AA_Households_Total                                                              -0.446895
# AA_Households_Rural                                                              -0.315159
# ...                                                                                    ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                           0.064631
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                          -0.049610
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                           0.000601
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                          -0.128872
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                           0.273249
#
#                                          ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit  \
# AA_Sample_Units_Total                                                   0.055085
# AA_Sample_Units_Rural                                                   0.095245
# AA_Sample_Units_Urban                                                  -0.036984
# AA_Households_Total                                                     0.155811
# AA_Households_Rural                                                     0.214719
# ...                                                                          ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                 0.867833
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                 0.945090
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                 0.817622
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                 0.369880
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                 0.347352
#
#                                          ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit  \
# AA_Sample_Units_Total                                                  -0.233965
# AA_Sample_Units_Rural                                                  -0.161355
# AA_Sample_Units_Urban                                                  -0.225313
# AA_Households_Total                                                    -0.221557
# AA_Households_Rural                                                    -0.156330
# ...                                                                          ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                 1.000000
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                 0.816740
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                 0.951709
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                 0.238832
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                 0.431214
#
#                                          ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit  \
# AA_Sample_Units_Total                                                   0.040244
# AA_Sample_Units_Rural                                                   0.115704
# AA_Sample_Units_Urban                                                  -0.099542
# AA_Households_Total                                                     0.141646
# AA_Households_Rural                                                     0.237102
# ...                                                                          ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                 0.816740
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                 1.000000
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                 0.840699
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                 0.164187
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                 0.217395
#
#                                          ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit  \
# AA_Sample_Units_Total                                                  -0.211274
# AA_Sample_Units_Rural                                                  -0.178947
# AA_Sample_Units_Urban                                                  -0.151190
# AA_Households_Total                                                    -0.208497
# AA_Households_Rural                                                    -0.188050
# ...                                                                          ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                 0.951709
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                 0.840699
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                 1.000000
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                 0.111252
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                 0.213575
#
#                                          ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit  \
# AA_Sample_Units_Total                                                   0.228764
# AA_Sample_Units_Rural                                                   0.078635
# AA_Sample_Units_Urban                                                   0.340372
# AA_Households_Total                                                     0.270664
# AA_Households_Rural                                                     0.131485
# ...                                                                          ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                 0.238832
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                 0.164187
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                 0.111252
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                 1.000000
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                 0.348455
#
#                                          ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit
# AA_Sample_Units_Total                                                  -0.252206
# AA_Sample_Units_Rural                                                  -0.087441
# AA_Sample_Units_Urban                                                  -0.374116
# AA_Households_Total                                                    -0.200014
# AA_Households_Rural                                                    -0.025769
# ...                                                                          ...
# ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit                                 0.431214
# ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit                                 0.217395
# ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit                                 0.213575
# ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit                                 0.348455
# ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit                                 1.000000
#
# [642 rows x 642 columns]

# %%
# Ordered correlation with target var
target_corr = dict(df.select_dtypes(include='number').corr()['YY_Infant_Mortality_Rate_Imr_Total_Person'])
sorted(target_corr.items(), key = lambda item: item[1])
# Out:
# [('AA_Ever_Married_Women_Aged_15_49_Years_Total',
#   np.float64(-0.46490693987258225)),
#  ('AA_Sample_Units_Total', np.float64(-0.46264395007808556)),
#  ('AA_Currently_Married_Women_Aged_15_49_Years_Total',
#   np.float64(-0.46131720709828333)),
#  ('AA_Households_Total', np.float64(-0.45026414495221373)),
#  ('AA_Population_Total', np.float64(-0.43469756366175855)),
#  ('AA_Ever_Married_Women_Aged_15_49_Years_Rural',
#   np.float64(-0.38507912203215633)),
#  ('AA_Currently_Married_Women_Aged_15_49_Years_Rural',
#   np.float64(-0.3801038049079371)),
#  ('AA_Sample_Units_Rural', np.float64(-0.37950860060501085)),
#  ('AA_Households_Rural', np.float64(-0.37738595510442596)),
#  ('AA_Sample_Units_Urban', np.float64(-0.3504900403988108)),
#  ('AA_Population_Rural', np.float64(-0.3503945573299793)),
#  ('AA_Ever_Married_Women_Aged_15_49_Years_Urban',
#   np.float64(-0.33271477750463474)),
#  ('AA_Currently_Married_Women_Aged_15_49_Years_Urban',
#   np.float64(-0.33103614806887954)),
#  ('AA_Population_Urban', np.float64(-0.32533802027461534)),
#  ('AA_Households_Urban', np.float64(-0.324506241149795)),
#  ('AA_Children_12_23_Months_Urban', np.float64(-0.3062868496789669)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Female_Total',
#   np.float64(-0.3051704827905074)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Person_Total',
#   np.float64(-0.2981892926314721)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Person_Urban',
#   np.float64(-0.29444471518299753)),
#  ('AA_Children_12_23_Months_Total', np.float64(-0.2891621949902702)),
#  ('DD_Person_Total', np.float64(-0.28846085800810817)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Female_Urban',
#   np.float64(-0.2874062032041151)),
#  ('DD_Female_Total', np.float64(-0.28326385784815206)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Male_Urban',
#   np.float64(-0.2828063661758168)),
#  ('DD_Male_Total', np.float64(-0.2825263048562702)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Female_Rural',
#   np.float64(-0.2731725755822613)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Male_Total',
#   np.float64(-0.26774244413796494)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Person_Rural',
#   np.float64(-0.26599654397274886)),
#  ('EE_Mean_Age_At_Marriage_Male_Total', np.float64(-0.2658531836468581)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Female_Rural',
#   np.float64(-0.2583011822810938)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Person_Rural',
#   np.float64(-0.2555395595938869)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Person_Total',
#   np.float64(-0.2550488595914355)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Female_Total',
#   np.float64(-0.2538539887664792)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Male_Total',
#   np.float64(-0.24785336449562473)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Male_Rural',
#   np.float64(-0.24634405368048456)),
#  ('DD_Person_Urban', np.float64(-0.24373975791572813)),
#  ('DD_Male_Rural', np.float64(-0.24291369470313193)),
#  ('DD_Person_Rural', np.float64(-0.24073080786092219)),
#  ('DD_Male_Urban', np.float64(-0.2370000200006611)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Male_Rural',
#   np.float64(-0.2359568995927696)),
#  ('EE_Mean_Age_At_Marriage_Male_Rural', np.float64(-0.2347986280351336)),
#  ('LL_Live_Births_Taking_Place_After_An_Interval_Of_36_Months_Total',
#   np.float64(-0.23037780262721314)),
#  ('DD_Female_Rural', np.float64(-0.22908847174904287)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Person_Urban',
#   np.float64(-0.22814770784492552)),
#  ('DD_Female_Urban', np.float64(-0.22444695296793868)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Male_Urban',
#   np.float64(-0.2161446635575268)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Female_Urban',
#   np.float64(-0.21451043113552615)),
#  ('LL_Live_Births_Taking_Place_After_An_Interval_Of_36_Months_Urban',
#   np.float64(-0.2080843054383822)),
#  ('AA_Children_12_23_Months_Rural', np.float64(-0.20237965460963306)),
#  ('LL_Live_Births_Taking_Place_After_An_Interval_Of_36_Months_Rural',
#   np.float64(-0.20099796148127153)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Person_Total',
#   np.float64(-0.1968653843702822)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Male_Total',
#   np.float64(-0.19532515568180944)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Female_Total',
#   np.float64(-0.18923242047494698)),
#  ('EE_Mean_Age_At_Marriage_Male_Urban', np.float64(-0.16609866865498438)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Female_Total',
#   np.float64(-0.14697076844092408)),
#  ('LL_Women_With_Two_Children_Wanting_No_More_Children_Total',
#   np.float64(-0.13497418941407283)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Female_Rural',
#   np.float64(-0.12996221494021654)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Male_Rural',
#   np.float64(-0.1290228712313481)),
#  ('LL_Women_With_Two_Children_Wanting_No_More_Children_Rural',
#   np.float64(-0.12751859253649842)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Person_Rural',
#   np.float64(-0.12613090792131643)),
#  ('EE_Currently_Married_Women_Aged_20_24_Years_Married_Before_Legal_Age_18_Years_Urban',
#   np.float64(-0.116816832996333)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Male_Rural',
#   np.float64(-0.11546410130301873)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Female_Rural',
#   np.float64(-0.1137596433985526)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Person_Rural',
#   np.float64(-0.11334611487532138)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Female_Rural',
#   np.float64(-0.10859194740779124)),
#  ('LL_Women_Aged_15_19_Years_Who_Were_Already_Mothers_Or_Pregnant_At_The_Time_Of_Survey_Total',
#   np.float64(-0.10755380960974188)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Person_Urban',
#   np.float64(-0.10699891407883637)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Male_Urban',
#   np.float64(-0.10528088060473695)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Male_Total',
#   np.float64(-0.10377249241189315)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Person_Total',
#   np.float64(-0.10270135748321758)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Male_Total',
#   np.float64(-0.10189518392686468)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Female_Urban',
#   np.float64(-0.10123493504669392)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Female_Total',
#   np.float64(-0.09923620075444105)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Male_Total',
#   np.float64(-0.0987225146476829)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Female_Urban',
#   np.float64(-0.09634856483392724)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Person_Rural',
#   np.float64(-0.08761078303194965)),
#  ('LL_Women_Aged_15_19_Years_Who_Were_Already_Mothers_Or_Pregnant_At_The_Time_Of_Survey_Rural',
#   np.float64(-0.08653283554033195)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Person_Total',
#   np.float64(-0.08465617279968528)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Male_Urban',
#   np.float64(-0.08322545449792981)),
#  ('LL_Women_Aged_20_24_Reporting_Birth_Of_Order_2__Above_Rural',
#   np.float64(-0.083152783753433)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_25_49_Years_Total',
#   np.float64(-0.08308346196685953)),
#  ('EE_Mean_Age_At_Marriage_Female_Total', np.float64(-0.08254041645162116)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Person_Total',
#   np.float64(-0.07859127857251226)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Female_Urban',
#   np.float64(-0.07281132458702612)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Female_Total',
#   np.float64(-0.07223296699302541)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Female_Total',
#   np.float64(-0.0714257961065372)),
#  ('LL_Women_Aged_20_24_Reporting_Birth_Of_Order_2__Above_Total',
#   np.float64(-0.07064200026315091)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Person_Total',
#   np.float64(-0.0695896236584548)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Female_Urban',
#   np.float64(-0.0631267414344745)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Female_Rural',
#   np.float64(-0.06280757111016087)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Male_Rural',
#   np.float64(-0.06169764446371004)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_15_49_Years_Total',
#   np.float64(-0.06139469048435934)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Person_Urban',
#   np.float64(-0.060924885647487347)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Male_Rural',
#   np.float64(-0.06071020852561871)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Male_Urban',
#   np.float64(-0.059693848368557074)),
#  ('CC_Sex_Ratio_All_Ages_Rural', np.float64(-0.05965082991682747)),
#  ('LL_Women_Aged_20_24_Reporting_Birth_Of_Order_2__Above_Urban',
#   np.float64(-0.05865910796030565)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Female_Total',
#   np.float64(-0.05698473225707289)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Male_Rural',
#   np.float64(-0.05529036663262723)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Female_Rural',
#   np.float64(-0.05519130272307099)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Person_Urban',
#   np.float64(-0.05173951885128805)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Female_Total',
#   np.float64(-0.05043336301735375)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Person_Rural',
#   np.float64(-0.050118829533928225)),
#  ('EE_Mean_Age_At_Marriage_Female_Rural', np.float64(-0.04942796403085633)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Person_Urban',
#   np.float64(-0.048710500959154704)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Male_Total',
#   np.float64(-0.04795196470346947)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Female_Total',
#   np.float64(-0.04769704971167627)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Person_Urban',
#   np.float64(-0.04733129420346925)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Person_Rural',
#   np.float64(-0.047252895523852985)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Male_Rural',
#   np.float64(-0.046169034609137176)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Person_Total',
#   np.float64(-0.04465943870888727)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Female_Rural',
#   np.float64(-0.043935523885567034)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Female_Rural',
#   np.float64(-0.04263239516119546)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Male_Rural',
#   np.float64(-0.04057588574437224)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Male_Urban',
#   np.float64(-0.04035498439151365)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Male_Total',
#   np.float64(-0.03969438168675031)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_25_49_Years_Rural',
#   np.float64(-0.039241324811676026)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Person_Rural',
#   np.float64(-0.03579704208622454)),
#  ('CC_Sex_Ratio_All_Ages_Total', np.float64(-0.03514646879856847)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Person_Urban',
#   np.float64(-0.03278526972683342)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Person_Total',
#   np.float64(-0.029498695365877358)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Person_Rural',
#   np.float64(-0.029286396904734745)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Female_Urban',
#   np.float64(-0.02877222732926456)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Female_Urban',
#   np.float64(-0.028687011328777507)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Person_Rural',
#   np.float64(-0.028390467366889268)),
#  ('EE_Marriages_Among_Females_Below_Legal_Age_18_Years_Urban',
#   np.float64(-0.02793354787237352)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Male_Urban',
#   np.float64(-0.026978087827771127)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Person_Total',
#   np.float64(-0.022980891403595858)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Female_Urban',
#   np.float64(-0.022284976469127596)),
#  ('LL_Women_With_Two_Children_Wanting_No_More_Children_Urban',
#   np.float64(-0.020299733558908798)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Male_Urban',
#   np.float64(-0.019793076097024163)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Female_Rural',
#   np.float64(-0.018547182741229285)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Female_Rural',
#   np.float64(-0.018298785412449038)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Person_Urban',
#   np.float64(-0.018185501873296074)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Male_Total',
#   np.float64(-0.017977019809039856)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Person_Rural',
#   np.float64(-0.017091214371096102)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_15_49_Years_Rural',
#   np.float64(-0.01646012938880813)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Female_Urban',
#   np.float64(-0.01625495117705202)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Person_Total',
#   np.float64(-0.013211720935042129)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_25_49_Years_Urban',
#   np.float64(-0.004850323950000147)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Female_Total',
#   np.float64(-0.004796898138766079)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Male_Urban',
#   np.float64(0.0012201308449363828)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Male_Urban',
#   np.float64(0.0025950243464045127)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Male_Total',
#   np.float64(0.0027747067873195416)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Male_Rural',
#   np.float64(0.006258135793541769)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Male_Total',
#   np.float64(0.007325068052276747)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Male_Rural',
#   np.float64(0.011133794777027863)),
#  ('LL_Women_Aged_15_19_Years_Who_Were_Already_Mothers_Or_Pregnant_At_The_Time_Of_Survey_Urban',
#   np.float64(0.014386404384903406)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Person_Total',
#   np.float64(0.019609711659645198)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Person_Rural',
#   np.float64(0.022510711758848473)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Female_Rural',
#   np.float64(0.022970087475456865)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Person_Urban',
#   np.float64(0.03253038094822691)),
#  ('BB_Average_Household_Size_Sc_Rural', np.float64(0.03300325058713546)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Male_Rural',
#   np.float64(0.033780949382255614)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_15_49_Years_Urban',
#   np.float64(0.03449133032484538)),
#  ('LL_Natural_Growth_Rate_Urban', np.float64(0.03545269115129676)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Female_Rural',
#   np.float64(0.03545987179954341)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Female_Rural',
#   np.float64(0.036603440346654095)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Female_Total',
#   np.float64(0.036814756727226096)),
#  ('BB_Average_Household_Size_Sc_Total', np.float64(0.03691076373441)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Female_Total',
#   np.float64(0.038850704817680735)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Female_Total',
#   np.float64(0.041385044698683766)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Person_Rural',
#   np.float64(0.041471891997134684)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Male_Total',
#   np.float64(0.04355036675825965)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Person_Urban',
#   np.float64(0.04507539808095017)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Female_Urban',
#   np.float64(0.04656406876077178)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Male_Rural',
#   np.float64(0.046578311621404)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Person_Total',
#   np.float64(0.0472173560507295)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Person_Urban',
#   np.float64(0.0473195304983961)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Male_Urban',
#   np.float64(0.047862663582221646)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Female_Urban',
#   np.float64(0.05024480680837301)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Female_Urban',
#   np.float64(0.0519501202085108)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Female_Urban',
#   np.float64(0.05426442923848095)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Male_Total',
#   np.float64(0.05546765326783183)),
#  ('CC_Sex_Ratio_All_Ages_Urban', np.float64(0.05782867359987358)),
#  ('CC_Sex_Ratio_At_Birth_Rural', np.float64(0.05826372950637777)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Female_Urban',
#   np.float64(0.0582856957033152)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Person_Urban',
#   np.float64(0.059734762189497255)),
#  ('CC_Sex_Ratio_0_4_Years_Rural', np.float64(0.06151406778925232)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Male_Rural',
#   np.float64(0.06506318573117965)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Male_Urban',
#   np.float64(0.06764560072644188)),
#  ('EE_Currently_Married_Women_Aged_20_24_Years_Married_Before_Legal_Age_18_Years_Rural',
#   np.float64(0.07488194385191643)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Female_Urban',
#   np.float64(0.07565710664007955)),
#  ('CC_Sex_Ratio_At_Birth_Total', np.float64(0.07572187524415662)),
#  ('BB_Average_Household_Size_Sc_Urban', np.float64(0.07618030742950974)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Female_Total',
#   np.float64(0.07624974642180278)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Male_Urban',
#   np.float64(0.07727386731443421)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Person_Total',
#   np.float64(0.07786711963682492)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Female_Urban',
#   np.float64(0.0783939819211075)),
#  ('EE_Mean_Age_At_Marriage_Female_Urban', np.float64(0.078746391571266)),
#  ('CC_Sex_Ratio_At_Birth_Urban', np.float64(0.08040103142162411)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Male_Total',
#   np.float64(0.08102054914652115)),
#  ('EE_Currently_Married_Women_Aged_20_24_Years_Married_Before_Legal_Age_18_Years_Total',
#   np.float64(0.08213741422089771)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Person_Rural',
#   np.float64(0.08228689311933521)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Male_Urban',
#   np.float64(0.08247226473752448)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Person_Rural',
#   np.float64(0.08368228855522243)),
#  ('EE_Marriages_Among_Females_Below_Legal_Age_18_Years_Rural',
#   np.float64(0.0839798909406019)),
#  ('EE_Marriages_Among_Males_Below_Legal_Age_21_Years_Urban',
#   np.float64(0.08538857173251124)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Person_Rural',
#   np.float64(0.08959009176618028)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Female_Rural',
#   np.float64(0.0898992925485869)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Person_Urban',
#   np.float64(0.09011492189879036)),
#  ('BB_Population_Below_Age_15_Years_Urban', np.float64(0.09034792227935283)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Male_Rural',
#   np.float64(0.09081844656466145)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Person_Urban',
#   np.float64(0.0909007664204872)),
#  ('CC_Sex_Ratio_0_4_Years_Total', np.float64(0.09723899873304474)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Female_Rural',
#   np.float64(0.09765262782430346)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Person_Urban',
#   np.float64(0.09852940996388944)),
#  ('EE_Marriages_Among_Females_Below_Legal_Age_18_Years_Total',
#   np.float64(0.09970080054734366)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Male_Urban',
#   np.float64(0.1012917040787699)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Male_Total',
#   np.float64(0.10261373618754557)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Female_Urban',
#   np.float64(0.10322943995860571)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Person_Urban',
#   np.float64(0.10455231173423156)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Male_Urban',
#   np.float64(0.1054639884034696)),
#  ('MM_Pregnancy_To_Women_Aged_15_49_Years_Resulting_In_Abortion_Total',
#   np.float64(0.1059805125689333)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Female_Urban',
#   np.float64(0.1073699469702813)),
#  ('CC_Sex_Ratio_0_4_Years_Urban', np.float64(0.10922581811823207)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Male_Urban',
#   np.float64(0.10983519012390845)),
#  ('EE_Currently_Married_Men_Aged_25_29_Years_Married_Before_Legal_Age_21_Years_Urban',
#   np.float64(0.11092569450132303)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Person_Total',
#   np.float64(0.1118124698840179)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Female_Total',
#   np.float64(0.11296692746023776)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Male_Rural',
#   np.float64(0.1146949269874071)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Person_Total',
#   np.float64(0.11573563049248792)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Person_Urban',
#   np.float64(0.11615459249315871)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Male_Total',
#   np.float64(0.11831954350790962)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Female_Total',
#   np.float64(0.11845769973251337)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Female_Total',
#   np.float64(0.11874000085395511)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Male_Urban',
#   np.float64(0.12113792479562804)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Male_Total',
#   np.float64(0.12122737161521337)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Person_Total',
#   np.float64(0.12289662371636503)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Person_Rural',
#   np.float64(0.12468084913246283)),
#  ('BB_Average_Household_Size_All_Rural', np.float64(0.1265545564367344)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Male_Urban',
#   np.float64(0.1282285107995894)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Female_Rural',
#   np.float64(0.1301182512049506)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Female_Rural',
#   np.float64(0.13107913244709346)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Person_Total',
#   np.float64(0.13232403088931158)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Male_Rural',
#   np.float64(0.13264743498346815)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Female_Urban',
#   np.float64(0.13494944742988688)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Person_Urban',
#   np.float64(0.13577435815090017)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Person_Rural',
#   np.float64(0.13611489123554302)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Female_Total',
#   np.float64(0.13648811537807218)),
#  ('BB_Dependency_Ratio_Urban', np.float64(0.13716941347132727)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Female_Rural',
#   np.float64(0.13797160166369613)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Person_Total',
#   np.float64(0.13874779333477555)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Female_Total',
#   np.float64(0.13943541599852122)),
#  ('BB_Average_Household_Size_St_Rural', np.float64(0.13963943454429212)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Female_Urban',
#   np.float64(0.14188605991296885)),
#  ('BB_Average_Household_Size_St_Total', np.float64(0.1441163902453545)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Female_Rural',
#   np.float64(0.14665023148108552)),
#  ('BB_Average_Household_Size_All_Total', np.float64(0.14748775403496162)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Person_Urban',
#   np.float64(0.15089259367869035)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Female_Rural',
#   np.float64(0.1517290500451691)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Person_Rural',
#   np.float64(0.1578789945356764)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Male_Urban',
#   np.float64(0.1581556243134369)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Person_Total',
#   np.float64(0.1591894540190584)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Female_Urban',
#   np.float64(0.15946038467616486)),
#  ('BB_Average_Household_Size_St_Urban', np.float64(0.16135691791482934)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Male_Total',
#   np.float64(0.162027145176979)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Female_Total',
#   np.float64(0.16223522051061165)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Male_Urban',
#   np.float64(0.1662672985116165)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Person_Total',
#   np.float64(0.16720245803366546)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Person_Urban',
#   np.float64(0.16924780534400108)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Person_Rural',
#   np.float64(0.16939919188500582)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Female_Total',
#   np.float64(0.1717433854368251)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Female_Rural',
#   np.float64(0.17218633898172941)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Male_Total',
#   np.float64(0.17331190831117896)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Person_Rural',
#   np.float64(0.17333640151220472)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Person_Urban',
#   np.float64(0.17436081202269077)),
#  ('LL_Mean_Number_Of_Children_Surviving_To_Women_Aged_15_49_Years_Urban',
#   np.float64(0.1744927926956559)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Male_Rural',
#   np.float64(0.1757232736057746)),
#  ('LL_Mean_Number_Of_Children_Surviving_To_Women_Aged_15_49_Years_Rural',
#   np.float64(0.17760401719276642)),
#  ('BB_Population_Below_Age_15_Years_Rural', np.float64(0.17850029450304278)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Male_Rural',
#   np.float64(0.1817342145029079)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Male_Total',
#   np.float64(0.18603916769799597)),
#  ('BB_Dependency_Ratio_Rural', np.float64(0.19101867783554494)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Female_Total',
#   np.float64(0.1947436416991233)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Male_Rural',
#   np.float64(0.1950626755033846)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Male_Rural',
#   np.float64(0.19711216543734184)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Person_Total',
#   np.float64(0.19969552061600176)),
#  ('BB_Currently_Married_Illiterate_Women_Aged_15_49_Years_Urban',
#   np.float64(0.19978889940997774)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Female_Rural',
#   np.float64(0.2002924923571045)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Person_Rural',
#   np.float64(0.2019112530032854)),
#  ('BB_Population_Below_Age_15_Years_Total', np.float64(0.2030208957992925)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Male_Rural',
#   np.float64(0.20344492016736626)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Male_Total',
#   np.float64(0.2045916917289332)),
#  ('LL_Mean_Number_Of_Children_Surviving_To_Women_Aged_15_49_Years_Total',
#   np.float64(0.20781462855753194)),
#  ('LL_Natural_Growth_Rate_Rural', np.float64(0.2124927748873432)),
#  ('BB_Dependency_Ratio_Total', np.float64(0.21627667587071397)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Male_Urban',
#   np.float64(0.2234485649803741)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Male_Total',
#   np.float64(0.2235112951236776)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Female_Urban',
#   np.float64(0.22680499590657974)),
#  ('LL_Crude_Birth_Rate_Cbr_Urban', np.float64(0.22998830228919426)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Person_Rural',
#   np.float64(0.23007547018438)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_15_49_Years_Urban',
#   np.float64(0.2300774570234835)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Male_Rural',
#   np.float64(0.23269882934114539)),
#  ('LL_Natural_Growth_Rate_Total', np.float64(0.23377512153002575)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Person_Rural',
#   np.float64(0.23391340158917487)),
#  ('BB_Average_Household_Size_All_Urban', np.float64(0.23739539250923503)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Person_Urban',
#   np.float64(0.2427280489762633)),
#  ('BB_Currently_Married_Illiterate_Women_Aged_15_49_Years_Rural',
#   np.float64(0.24360606877839783)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Male_Urban',
#   np.float64(0.2438634773984646)),
#  ('EE_Marriages_Among_Males_Below_Legal_Age_21_Years_Rural',
#   np.float64(0.2445372952422433)),
#  ('LL_Women_Reporting_Birth_Of_Order_3__Above_Urban',
#   np.float64(0.24693937580521766)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Female_Urban',
#   np.float64(0.24780558351572407)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Female_Rural',
#   np.float64(0.25299143208041247)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_45_49_Years_Urban',
#   np.float64(0.25437961562102096)),
#  ('EE_Currently_Married_Men_Aged_25_29_Years_Married_Before_Legal_Age_21_Years_Rural',
#   np.float64(0.2545448429204105)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Person_Total',
#   np.float64(0.25670476125202457)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Person_Total',
#   np.float64(0.26266737276503516)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_15_49_Years_Rural',
#   np.float64(0.26794077256245563)),
#  ('EE_Marriages_Among_Males_Below_Legal_Age_21_Years_Total',
#   np.float64(0.26897278337239444)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Male_Rural',
#   np.float64(0.2694295793293558)),
#  ('EE_Currently_Married_Men_Aged_25_29_Years_Married_Before_Legal_Age_21_Years_Total',
#   np.float64(0.27098593305198454)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Female_Total',
#   np.float64(0.28320415360415213)),
#  ('BB_Currently_Married_Illiterate_Women_Aged_15_49_Years_Total',
#   np.float64(0.2878997221891511)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Male_Total',
#   np.float64(0.28829098605309406)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_15_49_Years_Total',
#   np.float64(0.2924022638121796)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Male_Total',
#   np.float64(0.299015105367678)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_45_49_Years_Rural',
#   np.float64(0.3069939303517059)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Person_Urban',
#   np.float64(0.3200321939092346)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Male_Urban',
#   np.float64(0.3322933732728404)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_45_49_Years_Total',
#   np.float64(0.3358564062353798)),
#  ('LL_Women_Reporting_Birth_Of_Order_3__Above_Rural',
#   np.float64(0.33744791992328105)),
#  ('LL_Women_Reporting_Birth_Of_Order_3__Above_Total',
#   np.float64(0.3557543123701625)),
#  ('LL_Crude_Birth_Rate_Cbr_Rural', np.float64(0.45223049149151606)),
#  ('LL_Total_Fertility_Rate_Total', np.float64(0.453568053024274)),
#  ('LL_Crude_Birth_Rate_Cbr_Total', np.float64(0.47686511560300565)),
#  ('LL_Total_Fertility_Rate_Rural', np.float64(nan)),
#  ('LL_Total_Fertility_Rate_Urban', np.float64(nan)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Dpt_Vaccine_Total',
#   np.float64(-0.5447502905235537)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Dpt_Vaccine_Rural',
#   np.float64(-0.5424825638640728)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Polio_Vaccine_Rural',
#   np.float64(-0.5255400882544962)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Polio_Vaccine_Total',
#   np.float64(-0.524297292933966)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Bcg_Total',
#   np.float64(-0.5239726984600177)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Bcg_Rural',
#   np.float64(-0.5197321057657588)),
#  ('TT_Children_Aged_12_23_Months_Fully_Immunized_Rural',
#   np.float64(-0.5037178941789395)),
#  ('TT_Children_Aged_12_23_Months_Fully_Immunized_Total',
#   np.float64(-0.5022097019814096)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Measles_Vaccine_Rural',
#   np.float64(-0.5011378072216273)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Measles_Vaccine_Total',
#   np.float64(-0.4990135075932253)),
#  ('TT_Children_Aged_12_23_Months_Having_Immunization_Card_Total',
#   np.float64(-0.4257010382571323)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Dpt_Vaccine_Urban',
#   np.float64(-0.41615128567503407)),
#  ('TT_Children_Aged_12_23_Months_Having_Immunization_Card_Rural',
#   np.float64(-0.415473512472743)),
#  ('TT_Children_Aged_12_23_Months_Fully_Immunized_Urban',
#   np.float64(-0.3954476076137563)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Polio_Vaccine_Urban',
#   np.float64(-0.38951426141119305)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Bcg_Urban',
#   np.float64(-0.37059059072304573)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Measles_Vaccine_Urban',
#   np.float64(-0.3564562416634031)),
#  ('TT_Children_Aged_6_35_Months_Who_Received_At_Least_One_Vitamin_A_Dose_During_Last_Six_Months_Rural',
#   np.float64(-0.35256879756103116)),
#  ('TT_Children_Aged_6_35_Months_Who_Received_At_Least_One_Vitamin_A_Dose_During_Last_Six_Months_Total',
#   np.float64(-0.34851783436157857)),
#  ('TT_Children_Aged_12_23_Months_Having_Immunization_Card_Urban',
#   np.float64(-0.32277797049240353)),
#  ('PP_Mothers_Whose_Blood_Pressure_Bp_Taken_Total',
#   np.float64(-0.32276070614714414)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Water_Rural',
#   np.float64(-0.3226559909456665)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Water_Total',
#   np.float64(-0.31970930279386506)),
#  ('PP_Mothers_Whose_Blood_Pressure_Bp_Taken_Urban',
#   np.float64(-0.3090894876400219)),
#  ('PP_Mothers_Whose_Blood_Taken_For_Hb_Urban',
#   np.float64(-0.2997346314048006)),
#  ('PP_Mothers_Whose_Blood_Pressure_Bp_Taken_Rural',
#   np.float64(-0.2945525017782319)),
#  ('PP_Mothers_Whose_Blood_Taken_For_Hb_Total',
#   np.float64(-0.2826115654472257)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Water_Urban',
#   np.float64(-0.2750190196619147)),
#  ('PP_Mothers_Who_Had_Antenatal_Check_Up_In_First_Trimester_Total',
#   np.float64(-0.27457290049426863)),
#  ('PP_Mothers_Who_Received_At_Least_One_Tetanus_Toxoid_Tt_Injection_Total',
#   np.float64(-0.26606178562355287)),
#  ('PP_Mothers_Who_Consumed_Ifa_For_100_Days_Or_More_Total',
#   np.float64(-0.26031939059854875)),
#  ('PP_Mothers_Who_Underwent_Ultrasound_Total',
#   np.float64(-0.2544517486055935)),
#  ('NN_Current_Usage_Any_Modern_Method_Rural',
#   np.float64(-0.25411235143636846)),
#  ('PP_Mothers_Who_Received_At_Least_One_Tetanus_Toxoid_Tt_Injection_Urban',
#   np.float64(-0.25344678027122164)),
#  ('PP_Mothers_Who_Received_At_Least_One_Tetanus_Toxoid_Tt_Injection_Rural',
#   np.float64(-0.2505157519620541)),
#  ('QQ_Delivery_At_Private_Institution_Urban',
#   np.float64(-0.25023008815369174)),
#  ('VV_Children_Aged_6_35_Months_Exclusively_Breastfed_For_At_Least_Six_Months_Total',
#   np.float64(-0.24999743156002185)),
#  ('NN_Current_Usage_Any_Modern_Method_Total',
#   np.float64(-0.24816461102929452)),
#  ('PP_Mothers_Who_Had_Antenatal_Check_Up_In_First_Trimester_Urban',
#   np.float64(-0.24777786115868303)),
#  ('NN_Current_Usage_Female_Sterilization_Rural',
#   np.float64(-0.2471863564644468)),
#  ('PP_Mothers_Who_Received_Any_Antenatal_Check_Up_Total',
#   np.float64(-0.24625574846065193)),
#  ('PP_Mothers_Who_Had_Antenatal_Check_Up_In_First_Trimester_Rural',
#   np.float64(-0.24595100179678708)),
#  ('VV_Children_Aged_6_35_Months_Exclusively_Breastfed_For_At_Least_Six_Months_Rural',
#   np.float64(-0.24523064817676066)),
#  ('PP_Mothers_Whose_Blood_Taken_For_Hb_Rural',
#   np.float64(-0.24439950188103113)),
#  ('PP_Mothers_Who_Underwent_Ultrasound_Urban',
#   np.float64(-0.2432570990771731)),
#  ('PP_Mothers_Who_Had_Full_Antenatal_Check_Up_Total',
#   np.float64(-0.2411424663331426)),
#  ('NN_Current_Usage_Female_Sterilization_Total',
#   np.float64(-0.24067524986377725)),
#  ('PP_Mothers_Who_Received_Any_Antenatal_Check_Up_Urban',
#   np.float64(-0.2406505929816216)),
#  ('QQ_Delivery_At_Private_Institution_Total',
#   np.float64(-0.24033147350654857)),
#  ('PP_Mothers_Who_Received_Any_Antenatal_Check_Up_Rural',
#   np.float64(-0.23101775475189454)),
#  ('PP_Mothers_Who_Consumed_Ifa_For_100_Days_Or_More_Urban',
#   np.float64(-0.2262843491544793)),
#  ('XX_Women_Who_Are_Aware_Of_Hiv_Aids_Total',
#   np.float64(-0.22567268496584317)),
#  ('PP_Mothers_Who_Consumed_Ifa_For_100_Days_Or_More_Rural',
#   np.float64(-0.2252195053958912)),
#  ('PP_Mothers_Who_Received_3_Or_More_Antenatal_Care_Urban',
#   np.float64(-0.220411158132983)),
#  ('MM_Women_Who_Received_Any_Anc_Before_Abortion_Total',
#   np.float64(-0.21937556820281176)),
#  ('PP_Mothers_Who_Had_Full_Antenatal_Check_Up_Urban',
#   np.float64(-0.2187999244263088)),
#  ('RR_Mothers_Who_Did_Not_Receive_Any_Post_Natal_Check_Up_Rural',
#   np.float64(-0.218350569174906)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Animal_Formula_Milk_Rural',
#   np.float64(-0.2183099451246351)),
#  ('TT_Children_Whose_Birth_Weight_Was_Taken_Urban',
#   np.float64(-0.21787549283438967)),
#  ('TT_Children_Whose_Birth_Weight_Was_Taken_Total',
#   np.float64(-0.2175838761188929)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Animal_Formula_Milk_Total',
#   np.float64(-0.21725462104574672)),
#  ('PP_Mothers_Who_Received_3_Or_More_Antenatal_Care_Total',
#   np.float64(-0.21207291044738233)),
#  ('XX_Women_Who_Are_Aware_Of_Hiv_Aids_Rural',
#   np.float64(-0.21120896228561603)),
#  ('PP_Mothers_Who_Underwent_Ultrasound_Rural',
#   np.float64(-0.20528483723568366)),
#  ('VV_Children_Aged_6_35_Months_Exclusively_Breastfed_For_At_Least_Six_Months_Urban',
#   np.float64(-0.2040557379336899)),
#  ('RR_Mothers_Who_Did_Not_Receive_Any_Post_Natal_Check_Up_Total',
#   np.float64(-0.2025530564337578)),
#  ('PP_Currently_Married_Pregnant_Women_Aged_15_49_Years_Registered_For_Anc_Total',
#   np.float64(-0.20210560106786438)),
#  ('PP_Mothers_Who_Had_Full_Antenatal_Check_Up_Rural',
#   np.float64(-0.20209519417063004)),
#  ('VV_Children_Breastfed_Within_One_Hour_Of_Birth_Rural',
#   np.float64(-0.1989850205396018)),
#  ('PP_Currently_Married_Pregnant_Women_Aged_15_49_Years_Registered_For_Anc_Rural',
#   np.float64(-0.1985068980666688)),
#  ('MM_Women_Who_Received_Any_Anc_Before_Abortion_Rural',
#   np.float64(-0.19528999919531825)),
#  ('VV_Children_Breastfed_Within_One_Hour_Of_Birth_Total',
#   np.float64(-0.18860323410639127)),
#  ('PP_Mothers_Who_Received_3_Or_More_Antenatal_Care_Rural',
#   np.float64(-0.18477158745637487)),
#  ('TT_Children_Whose_Birth_Weight_Was_Taken_Rural',
#   np.float64(-0.18327968756329424)),
#  ('NN_Current_Usage_Female_Sterilization_Urban',
#   np.float64(-0.1763585366700027)),
#  ('MM_Women_Who_Went_For_Ultrasound_Before_Abortion_Total',
#   np.float64(-0.17528619490632125)),
#  ('TT_Children_Aged_6_35_Months_Who_Received_At_Least_One_Vitamin_A_Dose_During_Last_Six_Months_Urban',
#   np.float64(-0.17461403172995424)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Animal_Formula_Milk_Urban',
#   np.float64(-0.1731648485759311)),
#  ('TT_Children_Who_Have_Received_Polio_Dose_At_Birth_Urban',
#   np.float64(-0.16788826271999646)),
#  ('MM_Abortion_Performed_By_Skilled_Health_Personnel_Total',
#   np.float64(-0.16690858648000859)),
#  ('QQ_Delivery_At_Home_Conducted_By_Skilled_Health_Personnel_Total',
#   np.float64(-0.1665127385421802)),
#  ('PP_Currently_Married_Pregnant_Women_Aged_15_49_Years_Registered_For_Anc_Urban',
#   np.float64(-0.164931525426094)),
#  ('QQ_Delivery_At_Private_Institution_Rural',
#   np.float64(-0.15803238262336114)),
#  ('QQ_Delivery_At_Home_Conducted_By_Skilled_Health_Personnel_Rural',
#   np.float64(-0.1494981465427769)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Vegetables_Fruits_Rural',
#   np.float64(-0.14647788526325511)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Vegetables_Fruits_Total',
#   np.float64(-0.1456085547014061)),
#  ('MM_Abortion_Performed_By_Skilled_Health_Personnel_Urban',
#   np.float64(-0.1426250829912811)),
#  ('NN_Current_Usage_Male_Sterilization_Rural',
#   np.float64(-0.13976543646155656)),
#  ('MM_Abortion_Taking_Place_In_Institution_Urban',
#   np.float64(-0.13881235646606424)),
#  ('NN_Current_Usage_Male_Sterilization_Total',
#   np.float64(-0.13745239517932706)),
#  ('WW_Children_Whose_Birth_Was_Registered_And_Received_Birth_Certificate_Total',
#   np.float64(-0.13608382790201104)),
#  ('MM_Abortion_Taking_Place_In_Institution_Total',
#   np.float64(-0.13287203973218545)),
#  ('XX_Women_Who_Are_Aware_Of_Hiv_Aids_Urban', np.float64(-0.1306651698046456)),
#  ('MM_Women_Who_Went_For_Ultrasound_Before_Abortion_Rural',
#   np.float64(-0.13012836395088526)),
#  ('MM_Women_Who_Received_Any_Anc_Before_Abortion_Urban',
#   np.float64(-0.13005033118196532)),
#  ('TT_Children_Who_Have_Received_Polio_Dose_At_Birth_Total',
#   np.float64(-0.12943004370799152)),
#  ('MM_Abortion_Performed_By_Skilled_Health_Personnel_Rural',
#   np.float64(-0.12866997923822848)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Semi_Solid_Mashed_Food_Rural',
#   np.float64(-0.11943519558679368)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Semi_Solid_Mashed_Food_Total',
#   np.float64(-0.11935488636486112)),
#  ('WW_Birth_Registered_Urban', np.float64(-0.11820493746427589)),
#  ('RR_Mothers_Who_Did_Not_Receive_Any_Post_Natal_Check_Up_Urban',
# ...
#   np.float64(-0.0007297565893509116)),
#  ('NN_Current_Usage_Pills_Rural', np.float64(-6.576017651525556e-05)),
#  ('OO_Total_Unmet_Need_Urban', np.float64(0.00039579544976964053)),
#  ('QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Private_Institutions_Urban',
#   np.float64(0.0014285182078631387)),
#  ('TT_Children_Aged_6_35_Months_Who_Received_Ifa_Tablets_Syrup_During_Last_3_Months_Urban',
#   np.float64(0.001586933634801328)),
#  ('QQ_Safe_Delivery_Total', np.float64(0.002959820824462779)),
#  ('NN_Current_Usage_Pills_Total', np.float64(0.011120635601782163)),
#  ('XX_Women_Who_Are_Aware_Of_Rti_Sti_Rural', np.float64(0.01207471758244882)),
#  ('OO_Total_Unmet_Need_Total', np.float64(0.014085659268241117)),
#  ('MM_Average_Month_Of_Pregnancy_At_The_Time_Of_Abortion_Total',
#   np.float64(0.016292726412518787)),
#  ('OO_Total_Unmet_Need_Rural', np.float64(0.021235574562825054)),
#  ('QQ_Delivery_At_Home_Urban', np.float64(0.024426257844956403)),
#  ('NN_Current_Usage_Pills_Urban', np.float64(0.02524677088508418)),
#  ('NN_Current_Usage_Lam_Urban', np.float64(0.030188298079188377)),
#  ('XX_Women_Who_Are_Aware_Of_Danger_Signs_Of_Ari_Pneumonia_Urban',
#   np.float64(0.030395225488983737)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Animal_Formula_Milk_Urban',
#   np.float64(0.03901112631653453)),
#  ('XX_Women_Who_Are_Aware_Of_Danger_Signs_Of_Ari_Pneumonia_Total',
#   np.float64(0.039068634946675174)),
#  ('QQ_Safe_Delivery_Rural', np.float64(0.04020313831171059)),
#  ('UU_Children_Suffering_From_Diarrhoea_Who_Received_Haf_Ors_Ort_Urban',
#   np.float64(0.04279835923221904)),
#  ('QQ_Institutional_Delivery_Total', np.float64(0.04376957742284067)),
#  ('XX_Women_Who_Are_Aware_Of_Danger_Signs_Of_Ari_Pneumonia_Rural',
#   np.float64(0.05027801837297864)),
#  ('NN_Current_Usage_Any_Traditional_Method_Urban',
#   np.float64(0.05899432335525085)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Animal_Formula_Milk_Total',
#   np.float64(0.05918183106992068)),
#  ('NN_Current_Usage_Condom_Nirodh_Total', np.float64(0.060197006364871894)),
#  ('XX_Women_Who_Are_Aware_Of_Haf_Ors_Ort_Zinc_Urban',
#   np.float64(0.06296011753350747)),
#  ('TT_Children_With_Birth_Weight_Less_Than_2_5_Kg_Rural',
#   np.float64(0.06447254891158094)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Animal_Formula_Milk_Rural',
#   np.float64(0.0645930106955623)),
#  ('RR_Less_Than_24_Hrs_Stay_In_Institution_After_Delivery_Rural',
#   np.float64(0.0646749264255533)),
#  ('MM_Average_Month_Of_Pregnancy_At_The_Time_Of_Abortion_Urban',
#   np.float64(0.06942574415752926)),
#  ('OO_Unmet_Need_For_Limiting_Total', np.float64(0.07577141556714352)),
#  ('RR_Less_Than_24_Hrs_Stay_In_Institution_After_Delivery_Total',
#   np.float64(0.07649613220679446)),
#  ('UU_Children_Suffering_From_Acute_Respiratory_Infection_Who_Sought_Treatment_Total',
#   np.float64(0.08027396352665747)),
#  ('QQ_Institutional_Delivery_Rural', np.float64(0.08146418657967472)),
#  ('NN_Current_Usage_Lam_Rural', np.float64(0.08285360325906597)),
#  ('OO_Unmet_Need_For_Limiting_Rural', np.float64(0.08456096599542984)),
#  ('ZZ_Crude_Birth_Rate_Urban_Lower_Limit', np.float64(0.08682857644614905)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Water_Urban',
#   np.float64(0.08720151748024677)),
#  ('UU_Children_Suffering_From_Fever_Urban', np.float64(0.08793202296643995)),
#  ('OO_Unmet_Need_For_Limiting_Urban', np.float64(0.089082532254702)),
#  ('TT_Children_With_Birth_Weight_Less_Than_2_5_Kg_Total',
#   np.float64(0.08986324657121746)),
#  ('NN_Current_Usage_Condom_Nirodh_Rural', np.float64(0.09185275501309971)),
#  ('UU_Children_Suffering_From_Acute_Respiratory_Infection_Who_Sought_Treatment_Rural',
#   np.float64(0.09413464555676332)),
#  ('NN_Current_Usage_Lam_Total', np.float64(0.09594110350133894)),
#  ('OO_Unmet_Need_For_Spacing_Rural', np.float64(0.09815312399902622)),
#  ('OO_Unmet_Need_For_Spacing_Total', np.float64(0.09899618658543281)),
#  ('OO_Unmet_Need_For_Spacing_Urban', np.float64(0.10027926788746491)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Water_Rural',
#   np.float64(0.10119072095890988)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Water_Total',
#   np.float64(0.10279270203568061)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Solid_Adult_Food_Urban',
#   np.float64(0.10408316386358903)),
#  ('UU_Children_Suffering_From_Acute_Respiratory_Infection_Urban',
#   np.float64(0.1059913065267373)),
#  ('UU_Children_Suffering_From_Fever_Total', np.float64(0.10999102937050896)),
#  ('NN_Current_Usage_Periodic_Abstinence_Urban',
#   np.float64(0.11085732210497057)),
#  ('ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit', np.float64(0.11170801655649897)),
#  ('UU_Children_Suffering_From_Fever_Who_Sought_Treatment_Urban',
#   np.float64(0.11231568038462075)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_48_Hrs_Of_Delivery_Urban',
#   np.float64(0.11393193157649925)),
#  ('UU_Children_Suffering_From_Fever_Rural', np.float64(0.11431185585922485)),
#  ('MM_Pregnancy_To_Women_Aged_15_49_Years_Resulting_In_Abortion_Rural',
#   np.float64(0.11438661470335491)),
#  ('UU_Children_Suffering_From_Acute_Respiratory_Infection_Total',
#   np.float64(0.12916954300808842)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Delivery_Under_Jsy_Rural',
#   np.float64(0.12917286737938938)),
#  ('UU_Children_Suffering_From_Diarrhoea_Who_Received_Haf_Ors_Ort_Total',
#   np.float64(0.1337681898644265)),
#  ('UU_Children_Suffering_From_Acute_Respiratory_Infection_Rural',
#   np.float64(0.1359884687076578)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_1_Week_Of_Delivery_Urban',
#   np.float64(0.14154298463218168)),
#  ('QQ_Delivery_At_Government_Institution_Rural',
#   np.float64(0.1454870398516715)),
#  ('TT_Children_With_Birth_Weight_Less_Than_2_5_Kg_Urban',
#   np.float64(0.14597601718358266)),
#  ('UU_Children_Suffering_From_Diarrhoea_Who_Received_Haf_Ors_Ort_Rural',
#   np.float64(0.14627246637078653)),
#  ('ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit', np.float64(0.14678154085820747)),
#  ('NN_Current_Usage_Condom_Nirodh_Urban', np.float64(0.1476589988945467)),
#  ('NN_Current_Usage_Emergency_Contraceptive_Pills_Urban',
#   np.float64(0.15276961077682683)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Government_Institutional_Delivery_Under_Jsy_Rural',
#   np.float64(0.15592886771181552)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Delivery_Under_Jsy_Total',
#   np.float64(0.16197231518099187)),
#  ('QQ_Delivery_At_Government_Institution_Urban',
#   np.float64(0.1642347437807842)),
#  ('UU_Children_Suffering_From_Fever_Who_Sought_Treatment_Rural',
#   np.float64(0.16477197171693)),
#  ('QQ_Delivery_At_Government_Institution_Total',
#   np.float64(0.1648418505271392)),
#  ('ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit', np.float64(0.17003602290950304)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Solid_Adult_Food_Total',
#   np.float64(0.18174737628686874)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Institutional_Delivery_Under_Jsy_Rural',
#   np.float64(0.18174894792255442)),
#  ('RR_New_Borns_Who_Were_Checked_Up_Within_24_Hrs_Of_Birth_Urban',
#   np.float64(0.1822570693694089)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Solid_Adult_Food_Rural',
#   np.float64(0.1841634377809191)),
#  ('UU_Children_Suffering_From_Fever_Who_Sought_Treatment_Total',
#   np.float64(0.1867681373734616)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Delivery_Under_Jsy_Urban',
#   np.float64(0.19470031552568687)),
#  ('MM_Pregnancy_To_Women_Aged_15_49_Years_Resulting_In_Abortion_Urban',
#   np.float64(0.19572324262538088)),
#  ('NN_Current_Usage_Any_Traditional_Method_Total',
#   np.float64(0.20857631176225291)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_48_Hrs_Of_Delivery_Total',
#   np.float64(0.21223437658400454)),
#  ('UU_Children_Suffering_From_Diarrhoea_Urban',
#   np.float64(0.2125961019633622)),
#  ('PP_Mothers_Who_Received_Anc_From_Govt_Source_Urban',
#   np.float64(0.217613815285213)),
#  ('NN_Current_Usage_Any_Traditional_Method_Rural',
#   np.float64(0.217777746087367)),
#  ('UU_Children_Suffering_From_Diarrhoea_Rural',
#   np.float64(0.22093612622979897)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Government_Institutional_Delivery_Under_Jsy_Total',
#   np.float64(0.2231581417788763)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Institutional_Delivery_Under_Jsy_Urban',
#   np.float64(0.22771642132140257)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_48_Hrs_Of_Delivery_Rural',
#   np.float64(0.2280890652159767)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_1_Week_Of_Delivery_Total',
#   np.float64(0.23158987549693127)),
#  ('UU_Children_Suffering_From_Diarrhoea_Total',
#   np.float64(0.2339804045677632)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Government_Institutional_Delivery_Under_Jsy_Urban',
#   np.float64(0.24173516449590238)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Institutional_Delivery_Under_Jsy_Total',
#   np.float64(0.2421687545153142)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_1_Week_Of_Delivery_Rural',
#   np.float64(0.2485018202462471)),
#  ('RR_New_Borns_Who_Were_Checked_Up_Within_24_Hrs_Of_Birth_Total',
#   np.float64(0.25190297747057644)),
#  ('PP_Mothers_Who_Received_Anc_From_Govt_Source_Rural',
#   np.float64(0.25877939993203664)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Semi_Solid_Mashed_Food_Urban',
#   np.float64(0.2590872909758386)),
#  ('NN_Current_Usage_Emergency_Contraceptive_Pills_Rural',
#   np.float64(0.2644795052547603)),
#  ('NN_Current_Usage_Emergency_Contraceptive_Pills_Total',
#   np.float64(0.2661882637303293)),
#  ('PP_Mothers_Who_Received_Anc_From_Govt_Source_Total',
#   np.float64(0.2680178855374846)),
#  ('RR_New_Borns_Who_Were_Checked_Up_Within_24_Hrs_Of_Birth_Rural',
#   np.float64(0.2701847231491299)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Solid_Adult_Food_Urban',
#   np.float64(0.27128047454841697)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Semi_Solid_Mashed_Food_Rural',
#   np.float64(0.2933107944415878)),
#  ('NN_Current_Usage_Periodic_Abstinence_Total', np.float64(0.293486648987277)),
#  ('TT_Children_Who_Did_Not_Receive_Any_Vaccination_Urban',
#   np.float64(0.2949800543239659)),
#  ('ZZ_Crude_Birth_Rate_Urban_Upper_Limit', np.float64(0.2973405579857441)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Semi_Solid_Mashed_Food_Total',
#   np.float64(0.30176256779424926)),
#  ('NN_Current_Usage_Periodic_Abstinence_Rural',
#   np.float64(0.30724872451485274)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Solid_Adult_Food_Rural',
#   np.float64(0.3104224401921644)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Solid_Adult_Food_Total',
#   np.float64(0.3109080205370736)),
#  ('ZZ_Crude_Death_Rate_Urban_Lower_Limit', np.float64(0.3380318803683503)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Vegetables_Fruits_Urban',
#   np.float64(0.34650366235086305)),
#  ('YY_Crude_Death_Rate_Cdr_Urban_Male', np.float64(0.3528520605759526)),
#  ('YY_Post_Neo_Natal_Mortality_Rate_Urban', np.float64(0.3575860378737951)),
#  ('ZZ_Crude_Birth_Rate_Rural_Lower_Limit', np.float64(0.429089665164061)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Vegetables_Fruits_Total',
#   np.float64(0.44149780375661396)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Vegetables_Fruits_Rural',
#   np.float64(0.4428036617061857)),
#  ('YY_Crude_Death_Rate_Cdr_Urban_Person', np.float64(0.4441206821082019)),
#  ('ZZ_Crude_Birth_Rate_Total_Lower_Limit', np.float64(0.4451669075107137)),
#  ('TT_Children_Who_Did_Not_Receive_Any_Vaccination_Rural',
#   np.float64(0.44605864500040115)),
#  ('ZZ_Infant_Mortality_Rate_Urban_Lower_Limit',
#   np.float64(0.44908261044411424)),
#  ('TT_Children_Who_Did_Not_Receive_Any_Vaccination_Total',
#   np.float64(0.4523235795908568)),
#  ('ZZ_Crude_Death_Rate_Urban_Upper_Limit', np.float64(0.45882853555113673)),
#  ('YY_Crude_Death_Rate_Cdr_Urban_Female', np.float64(0.45891203287647947)),
#  ('YY_Infant_Mortality_Rate_Imr_Urban_Female',
#   np.float64(0.46665129291803514)),
#  ('ZZ_Crude_Birth_Rate_Rural_Upper_Limit', np.float64(0.4672715135890928)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit',
#   np.float64(0.4829728719402109)),
#  ('ZZ_Crude_Birth_Rate_Total_Upper_Limit', np.float64(0.4949278250163409)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Urban_Female',
#   np.float64(0.5048924671508095)),
#  ('YY_Crude_Death_Rate_Cdr_Rural_Male', np.float64(0.5923421011980391)),
#  ('YY_Crude_Death_Rate_Cdr_Total_Male', np.float64(0.6062160941371465)),
#  ('YY_Infant_Mortality_Rate_Imr_Urban_Male', np.float64(0.6134048057452518)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Urban_Male',
#   np.float64(0.624172382133961)),
#  ('YY_Post_Neo_Natal_Mortality_Rate_Rural', np.float64(0.6252515029535196)),
#  ('ZZ_Crude_Death_Rate_Rural_Lower_Limit', np.float64(0.6339953621648637)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Urban_Person',
#   np.float64(0.6387831512786808)),
#  ('ZZ_Crude_Death_Rate_Total_Lower_Limit', np.float64(0.6406901938078701)),
#  ('YY_Neo_Natal_Mortality_Rate_Urban', np.float64(0.6442708643712909)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit',
#   np.float64(0.6442841159733544)),
#  ('ZZ_Infant_Mortality_Rate_Urban_Upper_Limit',
#   np.float64(0.6551468031133184)),
#  ('YY_Post_Neo_Natal_Mortality_Rate_Total', np.float64(0.6599021629827129)),
#  ('YY_Crude_Death_Rate_Cdr_Rural_Person', np.float64(0.6645423257210631)),
#  ('YY_Infant_Mortality_Rate_Imr_Urban_Person', np.float64(0.6652250674991124)),
#  ('YY_Crude_Death_Rate_Cdr_Rural_Female', np.float64(0.6709612467165647)),
#  ('YY_Crude_Death_Rate_Cdr_Total_Person', np.float64(0.6803299656825813)),
#  ('ZZ_Crude_Death_Rate_Rural_Upper_Limit', np.float64(0.6898146819204819)),
#  ('YY_Crude_Death_Rate_Cdr_Total_Female', np.float64(0.6941370275545933)),
#  ('ZZ_Crude_Death_Rate_Total_Upper_Limit', np.float64(0.7037327426659008)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Rural_Female',
#   np.float64(0.8629202347780268)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Rural_Male',
#   np.float64(0.8775701224565233)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit',
#   np.float64(0.8872683191456789)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit',
#   np.float64(0.8884844842170778)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Rural_Person',
#   np.float64(0.8930580241727045)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Total_Female',
#   np.float64(0.8972713058702086)),
#  ('YY_Neo_Natal_Mortality_Rate_Rural', np.float64(0.9088141449650416)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Total_Male',
#   np.float64(0.9100100157424883)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Total_Lower_Limit',
#   np.float64(0.9117004924810503)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Total_Person',
#   np.float64(0.9208910771799288)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Total_Upper_Limit',
#   np.float64(0.9229440197601385)),
#  ('YY_Infant_Mortality_Rate_Imr_Rural_Female', np.float64(0.9256721552679721)),
#  ('YY_Neo_Natal_Mortality_Rate_Total', np.float64(0.9380860472173135)),
#  ('ZZ_Infant_Mortality_Rate_Rural_Upper_Limit',
#   np.float64(0.9410708802067292)),
#  ('YY_Infant_Mortality_Rate_Imr_Rural_Male', np.float64(0.9492109698955798)),
#  ('ZZ_Infant_Mortality_Rate_Rural_Lower_Limit',
#   np.float64(0.9574475266610009)),
#  ('YY_Infant_Mortality_Rate_Imr_Total_Female', np.float64(0.9713256207909062)),
#  ('YY_Infant_Mortality_Rate_Imr_Rural_Person', np.float64(0.9732719820782408)),
#  ('YY_Infant_Mortality_Rate_Imr_Total_Male', np.float64(0.9748249688514695)),
#  ('ZZ_Infant_Mortality_Rate_Total_Lower_Limit',
#   np.float64(0.9769601476785493)),
#  ('ZZ_Infant_Mortality_Rate_Total_Upper_Limit',
#   np.float64(0.9869407113480306)),
#  ('YY_Infant_Mortality_Rate_Imr_Total_Person', np.float64(1.0))]

# %%
# Columns representing totals
col_totals=[]
for c in df.columns:
    if 'Total' in c:
        col_totals.append(c)
col_totals
# Out:
# ['AA_Sample_Units_Total',
#  'AA_Households_Total',
#  'AA_Population_Total',
#  'AA_Ever_Married_Women_Aged_15_49_Years_Total',
#  'AA_Currently_Married_Women_Aged_15_49_Years_Total',
#  'AA_Children_12_23_Months_Total',
#  'BB_Average_Household_Size_Sc_Total',
#  'BB_Average_Household_Size_St_Total',
#  'BB_Average_Household_Size_All_Total',
#  'BB_Population_Below_Age_15_Years_Total',
#  'BB_Dependency_Ratio_Total',
#  'BB_Currently_Married_Illiterate_Women_Aged_15_49_Years_Total',
#  'CC_Sex_Ratio_At_Birth_Total',
#  'CC_Sex_Ratio_0_4_Years_Total',
#  'CC_Sex_Ratio_All_Ages_Total',
#  'DD_Person_Total',
#  'DD_Male_Total',
#  'DD_Female_Total',
#  'EE_Marriages_Among_Females_Below_Legal_Age_18_Years_Total',
#  'EE_Marriages_Among_Males_Below_Legal_Age_21_Years_Total',
#  'EE_Currently_Married_Women_Aged_20_24_Years_Married_Before_Legal_Age_18_Years_Total',
#  'EE_Currently_Married_Men_Aged_25_29_Years_Married_Before_Legal_Age_21_Years_Total',
#  'EE_Mean_Age_At_Marriage_Male_Total',
#  'EE_Mean_Age_At_Marriage_Female_Total',
#  'FF_Children_Currently_Attending_School_Age_6_17_Years_Person_Total',
#  'FF_Children_Currently_Attending_School_Age_6_17_Years_Male_Total',
#  'FF_Children_Currently_Attending_School_Age_6_17_Years_Female_Total',
#  'FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Person_Total',
#  'FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Male_Total',
#  'FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Female_Total',
#  'GG_Children_Aged_5_14_Years_Engaged_In_Work_Person_Total',
#  'GG_Children_Aged_5_14_Years_Engaged_In_Work_Male_Total',
#  'GG_Children_Aged_5_14_Years_Engaged_In_Work_Female_Total',
#  'GG_Work_Participation_Rate_15_Years_And_Above_Person_Total',
#  'GG_Work_Participation_Rate_15_Years_And_Above_Male_Total',
#  'GG_Work_Participation_Rate_15_Years_And_Above_Female_Total',
#  'HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Person_Total',
#  'HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Male_Total',
#  'HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Female_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Person_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Male_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Female_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Person_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Male_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Female_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Person_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Male_Total',
#  'II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Female_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Person_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Male_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Female_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Person_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Male_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Female_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Person_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Male_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Female_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Person_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Male_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Female_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Person_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Male_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Female_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Person_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Male_Total',
#  'JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Female_Total',
#  'KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Person_Total',
#  'KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Male_Total',
#  'KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Female_Total',
#  'KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Person_Total',
#  'KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Male_Total',
#  'KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Female_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Person_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Male_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Female_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Person_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Male_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Female_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Person_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Male_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Female_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Person_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Male_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Female_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Person_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Male_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Female_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Person_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Male_Total',
#  'KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Female_Total',
#  'KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Person_Total',
#  'KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Male_Total',
#  'KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Female_Total',
#  'KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Person_Total',
#  'KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Male_Total',
#  'KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Female_Total',
#  'LL_Crude_Birth_Rate_Cbr_Total',
#  'LL_Natural_Growth_Rate_Total',
#  'LL_Total_Fertility_Rate_Total',
#  'LL_Total_Fertility_Rate_Rural',
#  'LL_Total_Fertility_Rate_Urban',
#  'LL_Women_Aged_20_24_Reporting_Birth_Of_Order_2__Above_Total',
#  'LL_Women_Reporting_Birth_Of_Order_3__Above_Total',
#  'LL_Women_With_Two_Children_Wanting_No_More_Children_Total',
#  'LL_Women_Aged_15_19_Years_Who_Were_Already_Mothers_Or_Pregnant_At_The_Time_Of_Survey_Total',
#  'LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_15_49_Years_Total',
#  'LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_25_49_Years_Total',
#  'LL_Live_Births_Taking_Place_After_An_Interval_Of_36_Months_Total',
#  'LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_15_49_Years_Total',
#  'LL_Mean_Number_Of_Children_Surviving_To_Women_Aged_15_49_Years_Total',
#  'LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_45_49_Years_Total',
#  'MM_Pregnancy_To_Women_Aged_15_49_Years_Resulting_In_Abortion_Total',
#  'MM_Women_Who_Received_Any_Anc_Before_Abortion_Total',
#  'MM_Women_Who_Went_For_Ultrasound_Before_Abortion_Total',
#  'MM_Average_Month_Of_Pregnancy_At_The_Time_Of_Abortion_Total',
#  'MM_Abortion_Performed_By_Skilled_Health_Personnel_Total',
#  'MM_Abortion_Taking_Place_In_Institution_Total',
#  'NN_Current_Usage_Any_Method_Total',
#  'NN_Current_Usage_Any_Modern_Method_Total',
#  'NN_Current_Usage_Female_Sterilization_Total',
#  'NN_Current_Usage_Male_Sterilization_Total',
#  'NN_Current_Usage_Copper_T_Iud_Total',
#  'NN_Current_Usage_Pills_Total',
#  'NN_Current_Usage_Condom_Nirodh_Total',
#  'NN_Current_Usage_Emergency_Contraceptive_Pills_Total',
#  'NN_Current_Usage_Any_Traditional_Method_Total',
#  'NN_Current_Usage_Periodic_Abstinence_Total',
#  'NN_Current_Usage_Withdrawal_Total',
#  'NN_Current_Usage_Lam_Total',
#  'OO_Unmet_Need_For_Spacing_Total',
#  'OO_Unmet_Need_For_Limiting_Total',
#  'OO_Total_Unmet_Need_Total',
#  'OO_Total_Unmet_Need_Rural',
#  'OO_Total_Unmet_Need_Urban',
#  'PP_Currently_Married_Pregnant_Women_Aged_15_49_Years_Registered_For_Anc_Total',
#  'PP_Mothers_Who_Received_Any_Antenatal_Check_Up_Total',
#  'PP_Mothers_Who_Had_Antenatal_Check_Up_In_First_Trimester_Total',
#  'PP_Mothers_Who_Received_3_Or_More_Antenatal_Care_Total',
#  'PP_Mothers_Who_Received_At_Least_One_Tetanus_Toxoid_Tt_Injection_Total',
#  'PP_Mothers_Who_Consumed_Ifa_For_100_Days_Or_More_Total',
#  'PP_Mothers_Who_Had_Full_Antenatal_Check_Up_Total',
#  'PP_Mothers_Who_Received_Anc_From_Govt_Source_Total',
#  'PP_Mothers_Whose_Blood_Pressure_Bp_Taken_Total',
#  'PP_Mothers_Whose_Blood_Taken_For_Hb_Total',
#  'PP_Mothers_Who_Underwent_Ultrasound_Total',
#  'QQ_Institutional_Delivery_Total',
#  'QQ_Delivery_At_Government_Institution_Total',
#  'QQ_Delivery_At_Private_Institution_Total',
#  'QQ_Delivery_At_Home_Total',
#  'QQ_Delivery_At_Home_Conducted_By_Skilled_Health_Personnel_Total',
#  'QQ_Safe_Delivery_Total',
#  'QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Government_Institutions_Total',
#  'QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Government_Institutions_Rural',
#  'QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Government_Institutions_Urban',
#  'QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Private_Institutions_Total',
#  'QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Private_Institutions_Rural',
#  'QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Private_Institutions_Urban',
#  'RR_Less_Than_24_Hrs_Stay_In_Institution_After_Delivery_Total',
#  'RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_48_Hrs_Of_Delivery_Total',
#  'RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_1_Week_Of_Delivery_Total',
#  'RR_Mothers_Who_Did_Not_Receive_Any_Post_Natal_Check_Up_Total',
#  'RR_New_Borns_Who_Were_Checked_Up_Within_24_Hrs_Of_Birth_Total',
#  'SS_Mothers_Who_Availed_Financial_Assistance_For_Delivery_Under_Jsy_Total',
#  'SS_Mothers_Who_Availed_Financial_Assistance_For_Institutional_Delivery_Under_Jsy_Total',
#  'SS_Mothers_Who_Availed_Financial_Assistance_For_Government_Institutional_Delivery_Under_Jsy_Total',
#  'TT_Children_Aged_12_23_Months_Having_Immunization_Card_Total',
#  'TT_Children_Aged_12_23_Months_Who_Have_Received_Bcg_Total',
#  'TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Polio_Vaccine_Total',
#  'TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Dpt_Vaccine_Total',
#  'TT_Children_Aged_12_23_Months_Who_Have_Received_Measles_Vaccine_Total',
#  'TT_Children_Aged_12_23_Months_Fully_Immunized_Total',
#  'TT_Children_Who_Have_Received_Polio_Dose_At_Birth_Total',
#  'TT_Children_Who_Did_Not_Receive_Any_Vaccination_Total',
#  'TT_Children_Aged_6_35_Months_Who_Received_At_Least_One_Vitamin_A_Dose_During_Last_Six_Months_Total',
#  'TT_Children_Aged_6_35_Months_Who_Received_Ifa_Tablets_Syrup_During_Last_3_Months_Total',
#  'TT_Children_Whose_Birth_Weight_Was_Taken_Total',
#  'TT_Children_With_Birth_Weight_Less_Than_2_5_Kg_Total',
#  'UU_Children_Suffering_From_Diarrhoea_Total',
#  'UU_Children_Suffering_From_Diarrhoea_Who_Received_Haf_Ors_Ort_Total',
#  'UU_Children_Suffering_From_Acute_Respiratory_Infection_Total',
#  'UU_Children_Suffering_From_Acute_Respiratory_Infection_Who_Sought_Treatment_Total',
#  'UU_Children_Suffering_From_Fever_Total',
#  'UU_Children_Suffering_From_Fever_Who_Sought_Treatment_Total',
#  'VV_Children_Breastfed_Within_One_Hour_Of_Birth_Total',
#  'VV_Children_Aged_6_35_Months_Exclusively_Breastfed_For_At_Least_Six_Months_Total',
#  'VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Water_Total',
#  'VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Animal_Formula_Milk_Total',
#  'VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Semi_Solid_Mashed_Food_Total',
#  'VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Solid_Adult_Food_Total',
#  'VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Vegetables_Fruits_Total',
#  'VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Water_Total',
#  'VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Animal_Formula_Milk_Total',
#  'VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Semi_Solid_Mashed_Food_Total',
#  'VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Solid_Adult_Food_Total',
#  'VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Vegetables_Fruits_Total',
#  'WW_Birth_Registered_Total',
#  'WW_Children_Whose_Birth_Was_Registered_And_Received_Birth_Certificate_Total',
#  'XX_Women_Who_Are_Aware_Of_Hiv_Aids_Total',
#  'XX_Women_Who_Are_Aware_Of_Rti_Sti_Total',
#  'XX_Women_Who_Are_Aware_Of_Haf_Ors_Ort_Zinc_Total',
#  'XX_Women_Who_Are_Aware_Of_Danger_Signs_Of_Ari_Pneumonia_Total',
#  'YY_Crude_Death_Rate_Cdr_Total_Person',
#  'YY_Crude_Death_Rate_Cdr_Total_Male',
#  'YY_Crude_Death_Rate_Cdr_Total_Female',
#  'YY_Infant_Mortality_Rate_Imr_Total_Person',
#  'YY_Infant_Mortality_Rate_Imr_Total_Male',
#  'YY_Infant_Mortality_Rate_Imr_Total_Female',
#  'YY_Neo_Natal_Mortality_Rate_Total',
#  'YY_Post_Neo_Natal_Mortality_Rate_Total',
#  'YY_Under_Five_Mortality_Rate_U5MR_Total_Person',
#  'YY_Under_Five_Mortality_Rate_U5MR_Total_Male',
#  'YY_Under_Five_Mortality_Rate_U5MR_Total_Female',
#  'ZZ_Crude_Birth_Rate_Total_Lower_Limit',
#  'ZZ_Crude_Birth_Rate_Total_Upper_Limit',
#  'ZZ_Crude_Death_Rate_Total_Lower_Limit',
#  'ZZ_Crude_Death_Rate_Total_Upper_Limit',
#  'ZZ_Infant_Mortality_Rate_Total_Lower_Limit',
#  'ZZ_Infant_Mortality_Rate_Total_Upper_Limit',
#  'ZZ_Under_Five_Mortality_Rate_U5MR_Total_Lower_Limit',
#  'ZZ_Under_Five_Mortality_Rate_U5MR_Total_Upper_Limit',
#  'ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit',
#  'ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit']

# %%
# Distributions for variable totals
for c in col_totals:
    plt.hist(df[c]), plt.title(c)
    plt.show()
# Out:
# /home/rc/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/matplotlib/axes/_axes.py:7104: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/rc/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/matplotlib/axes/_axes.py:7105: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Distributions for variable totals
#       2 for c in col_totals:
# ----> 3     plt.hist(df[c]), plt.title(c)
#       4     plt.show()
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/matplotlib/pyplot.py:3478, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3453 @_copy_docstring_and_deprecators(Axes.hist)
#    3454 def hist(
#    3455     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3476     BarContainer | Polygon | list[BarContainer | Polygon],
#    3477 ]:
# -> 3478     return gca().hist(
#    3479         x,
#    3480         bins=bins,
#    3481         range=range,
#    3482         density=density,
#    3483         weights=weights,
#    3484         cumulative=cumulative,
#    3485         bottom=bottom,
#    3486         histtype=histtype,
#    3487         align=align,
#    3488         orientation=orientation,
#    3489         rwidth=rwidth,
#    3490         log=log,
#    3491         color=color,
#    3492         label=label,
#    3493         stacked=stacked,
#    3494         **({"data": data} if data is not None else {}),
#    3495         **kwargs,
#    3496     )
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/matplotlib/axes/_axes.py:7132, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7128 # Loop through datasets
#    7129 for i in range(nx):
#    7130     # this will automatically overwrite bins,
#    7131     # so that each histogram uses the same bins
# -> 7132     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7133     tops.append(m)
#    7134 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/numpy/lib/_histograms_impl.py:792, in histogram(a, bins, range, density, weights)
#     687 r"""
#     688 Compute the histogram of a dataset.
#     689
#    (...)    788
#     789 """
#     790 a, weights = _ravel_and_check_weights(a, weights)
# --> 792 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     794 # Histogram is an integer or a float array depending on the weights.
#     795 if weights is None:
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/numpy/lib/_histograms_impl.py:425, in _get_bin_edges(a, bins, range, weights)
#     422     if n_equal_bins < 1:
#     423         raise ValueError('`bins` must be positive, when an integer')
# --> 425     first_edge, last_edge = _get_outer_edges(a, range)
#     427 elif np.ndim(bins) == 1:
#     428     bin_edges = np.asarray(bins)
#
# File ~/Academia/capstone/.pixi/envs/default/lib/python3.14/site-packages/numpy/lib/_histograms_impl.py:317, in _get_outer_edges(a, range)
#     315     first_edge, last_edge = a.min(), a.max()
#     316     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 317         raise ValueError(
#     318             f"autodetected range of [{first_edge}, {last_edge}] is not finite")
#     320 # expand empty range to avoid divide by zero
#     321 if first_edge == last_edge:
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
## Null values for each feature with nulls
null_counts = nullcount(df)
has_null = dict()
for k,v in null_counts.items():
    if v>0:
        has_null[k]=v
sorted(has_null.items(), key = lambda item: item[1])
# Out:
# [('BB_Average_Household_Size_St_Urban', np.int64(1)),
#  ('LL_Crude_Birth_Rate_Cbr_Urban', np.int64(1)),
#  ('ZZ_Crude_Birth_Rate_Urban_Lower_Limit', np.int64(1)),
#  ('ZZ_Crude_Birth_Rate_Urban_Upper_Limit', np.int64(1)),
#  ('CC_Sex_Ratio_At_Birth_Urban', np.int64(3)),
#  ('LL_Natural_Growth_Rate_Urban', np.int64(3)),
#  ('YY_Crude_Death_Rate_Cdr_Urban_Person', np.int64(3)),
#  ('YY_Crude_Death_Rate_Cdr_Urban_Male', np.int64(3)),
#  ('YY_Crude_Death_Rate_Cdr_Urban_Female', np.int64(3)),
#  ('ZZ_Crude_Death_Rate_Urban_Lower_Limit', np.int64(3)),
#  ('ZZ_Crude_Death_Rate_Urban_Upper_Limit', np.int64(3)),
#  ('ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit', np.int64(9)),
#  ('ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit', np.int64(9)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Person_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Male_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Acute_Respiratory_Infection_Ari_Female_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Person_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Male_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Fever_All_Types_Female_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Person_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Male_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Any_Type_Of_Acute_Illness_Female_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Person_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Male_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Any_Source_Female_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Person_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Male_Urban',
#   np.int64(44)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_And_Taking_Treatment_From_Government_Source_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_Per_100000_Population_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Any_Kind_Of_Symptoms_Of_Chronic_Illness_And_Sought_Medical_Care_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Diabetes_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Hypertension_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Tuberculosis_Tb_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Asthma_Chronic_Respiratory_Disease_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Arthritis_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Chronic_Illness_Per_100000_Population_Any_Kind_Of_Chronic_Illness_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_Female_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Person_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Male_Urban',
#   np.int64(44)),
#  ('KK_Having_Diagnosed_For_Any_Kind_Of_Chronic_Illness_And_Getting_Regular_Treatment_From_Government_Source_Female_Urban',
#   np.int64(44)),
#  ('LL_Women_Aged_20_24_Reporting_Birth_Of_Order_2__Above_Urban', np.int64(44)),
#  ('LL_Women_Reporting_Birth_Of_Order_3__Above_Urban', np.int64(44)),
#  ('LL_Women_With_Two_Children_Wanting_No_More_Children_Urban', np.int64(44)),
#  ('LL_Women_Aged_15_19_Years_Who_Were_Already_Mothers_Or_Pregnant_At_The_Time_Of_Survey_Urban',
#   np.int64(44)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_15_49_Years_Urban',
#   np.int64(44)),
#  ('LL_Median_Age_At_First_Live_Birth_Of_Women_Aged_25_49_Years_Urban',
#   np.int64(44)),
#  ('LL_Live_Births_Taking_Place_After_An_Interval_Of_36_Months_Urban',
#   np.int64(44)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_15_49_Years_Urban',
#   np.int64(44)),
#  ('LL_Mean_Number_Of_Children_Surviving_To_Women_Aged_15_49_Years_Urban',
#   np.int64(44)),
#  ('LL_Mean_Number_Of_Children_Ever_Born_To_Women_Aged_45_49_Years_Urban',
#   np.int64(44)),
#  ('MM_Pregnancy_To_Women_Aged_15_49_Years_Resulting_In_Abortion_Urban',
#   np.int64(44)),
#  ('MM_Women_Who_Received_Any_Anc_Before_Abortion_Urban', np.int64(44)),
#  ('MM_Women_Who_Went_For_Ultrasound_Before_Abortion_Urban', np.int64(44)),
#  ('MM_Average_Month_Of_Pregnancy_At_The_Time_Of_Abortion_Urban', np.int64(44)),
#  ('MM_Abortion_Performed_By_Skilled_Health_Personnel_Urban', np.int64(44)),
#  ('MM_Abortion_Taking_Place_In_Institution_Urban', np.int64(44)),
#  ('NN_Current_Usage_Any_Method_Urban', np.int64(44)),
#  ('NN_Current_Usage_Any_Modern_Method_Urban', np.int64(44)),
#  ('NN_Current_Usage_Female_Sterilization_Urban', np.int64(44)),
#  ('NN_Current_Usage_Male_Sterilization_Urban', np.int64(44)),
#  ('NN_Current_Usage_Copper_T_Iud_Urban', np.int64(44)),
#  ('NN_Current_Usage_Pills_Urban', np.int64(44)),
#  ('NN_Current_Usage_Condom_Nirodh_Urban', np.int64(44)),
#  ('NN_Current_Usage_Emergency_Contraceptive_Pills_Urban', np.int64(44)),
#  ('NN_Current_Usage_Any_Traditional_Method_Urban', np.int64(44)),
#  ('NN_Current_Usage_Periodic_Abstinence_Urban', np.int64(44)),
#  ('NN_Current_Usage_Withdrawal_Urban', np.int64(44)),
#  ('NN_Current_Usage_Lam_Urban', np.int64(44)),
#  ('OO_Unmet_Need_For_Spacing_Urban', np.int64(44)),
#  ('OO_Unmet_Need_For_Limiting_Urban', np.int64(44)),
#  ('OO_Total_Unmet_Need_Urban', np.int64(44)),
#  ('PP_Currently_Married_Pregnant_Women_Aged_15_49_Years_Registered_For_Anc_Urban',
#   np.int64(44)),
#  ('PP_Mothers_Who_Received_Any_Antenatal_Check_Up_Urban', np.int64(44)),
#  ('PP_Mothers_Who_Had_Antenatal_Check_Up_In_First_Trimester_Urban',
#   np.int64(44)),
#  ('PP_Mothers_Who_Received_3_Or_More_Antenatal_Care_Urban', np.int64(44)),
#  ('PP_Mothers_Who_Received_At_Least_One_Tetanus_Toxoid_Tt_Injection_Urban',
#   np.int64(44)),
#  ('PP_Mothers_Who_Consumed_Ifa_For_100_Days_Or_More_Urban', np.int64(44)),
#  ('PP_Mothers_Who_Had_Full_Antenatal_Check_Up_Urban', np.int64(44)),
#  ('PP_Mothers_Who_Received_Anc_From_Govt_Source_Urban', np.int64(44)),
#  ('PP_Mothers_Whose_Blood_Pressure_Bp_Taken_Urban', np.int64(44)),
#  ('PP_Mothers_Whose_Blood_Taken_For_Hb_Urban', np.int64(44)),
#  ('PP_Mothers_Who_Underwent_Ultrasound_Urban', np.int64(44)),
#  ('QQ_Institutional_Delivery_Urban', np.int64(44)),
#  ('QQ_Delivery_At_Government_Institution_Urban', np.int64(44)),
#  ('QQ_Delivery_At_Private_Institution_Urban', np.int64(44)),
#  ('QQ_Delivery_At_Home_Urban', np.int64(44)),
#  ('QQ_Delivery_At_Home_Conducted_By_Skilled_Health_Personnel_Urban',
#   np.int64(44)),
#  ('QQ_Safe_Delivery_Urban', np.int64(44)),
#  ('QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Government_Institutions_Urban',
#   np.int64(44)),
#  ('QQ_Caesarean_Out_Of_Total_Delivery_Taken_Place_In_Private_Institutions_Urban',
#   np.int64(44)),
#  ('RR_Less_Than_24_Hrs_Stay_In_Institution_After_Delivery_Urban',
#   np.int64(44)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_48_Hrs_Of_Delivery_Urban',
#   np.int64(44)),
#  ('RR_Mothers_Who_Received_Post_Natal_Check_Up_Within_1_Week_Of_Delivery_Urban',
#   np.int64(44)),
#  ('RR_Mothers_Who_Did_Not_Receive_Any_Post_Natal_Check_Up_Urban',
#   np.int64(44)),
#  ('RR_New_Borns_Who_Were_Checked_Up_Within_24_Hrs_Of_Birth_Urban',
#   np.int64(44)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Delivery_Under_Jsy_Urban',
#   np.int64(44)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Institutional_Delivery_Under_Jsy_Urban',
#   np.int64(44)),
#  ('SS_Mothers_Who_Availed_Financial_Assistance_For_Government_Institutional_Delivery_Under_Jsy_Urban',
#   np.int64(44)),
#  ('EE_Marriages_Among_Females_Below_Legal_Age_18_Years_Urban', np.int64(45)),
#  ('EE_Marriages_Among_Males_Below_Legal_Age_21_Years_Urban', np.int64(45)),
#  ('EE_Currently_Married_Women_Aged_20_24_Years_Married_Before_Legal_Age_18_Years_Urban',
#   np.int64(45)),
#  ('EE_Currently_Married_Men_Aged_25_29_Years_Married_Before_Legal_Age_21_Years_Urban',
#   np.int64(45)),
#  ('EE_Mean_Age_At_Marriage_Male_Urban', np.int64(45)),
#  ('EE_Mean_Age_At_Marriage_Female_Urban', np.int64(45)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Person_Urban',
#   np.int64(45)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Male_Urban',
#   np.int64(45)),
#  ('FF_Children_Currently_Attending_School_Age_6_17_Years_Female_Urban',
#   np.int64(45)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Person_Urban',
#   np.int64(45)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Male_Urban',
#   np.int64(45)),
#  ('FF_Children_Attended_Before_Drop_Out_Age_6_17_Years_Female_Urban',
#   np.int64(45)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Person_Urban', np.int64(45)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Male_Urban', np.int64(45)),
#  ('GG_Children_Aged_5_14_Years_Engaged_In_Work_Female_Urban', np.int64(45)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Person_Urban', np.int64(45)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Male_Urban', np.int64(45)),
#  ('GG_Work_Participation_Rate_15_Years_And_Above_Female_Urban', np.int64(45)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Person_Urban',
#   np.int64(45)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Male_Urban',
#   np.int64(45)),
#  ('HH_Prevalence_Of_Any_Type_Of_Disability_Per_100000_Population_Female_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Person_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Male_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Severe_Female_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Person_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Male_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Major_Female_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Person_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Male_Urban',
#   np.int64(45)),
#  ('II_Number_Of_Injured_Persons_By_Type_Of_Treatment_Received_Per_100000_Population_Minor_Female_Urban',
#   np.int64(45)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Person_Urban',
#   np.int64(45)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Male_Urban',
#   np.int64(45)),
#  ('JJ_Persons_Suffering_From_Acute_Illness_Per_100000_Population_Diarrhoea_Dysentery_Female_Urban',
#   np.int64(45)),
#  ('TT_Children_Aged_12_23_Months_Having_Immunization_Card_Urban',
#   np.int64(45)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Bcg_Urban', np.int64(45)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Polio_Vaccine_Urban',
#   np.int64(45)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_3_Doses_Of_Dpt_Vaccine_Urban',
#   np.int64(45)),
#  ('TT_Children_Aged_12_23_Months_Who_Have_Received_Measles_Vaccine_Urban',
#   np.int64(45)),
#  ('TT_Children_Aged_12_23_Months_Fully_Immunized_Urban', np.int64(45)),
#  ('TT_Children_Who_Have_Received_Polio_Dose_At_Birth_Urban', np.int64(45)),
#  ('TT_Children_Who_Did_Not_Receive_Any_Vaccination_Urban', np.int64(45)),
#  ('TT_Children_Aged_6_35_Months_Who_Received_At_Least_One_Vitamin_A_Dose_During_Last_Six_Months_Urban',
#   np.int64(45)),
#  ('TT_Children_Aged_6_35_Months_Who_Received_Ifa_Tablets_Syrup_During_Last_3_Months_Urban',
#   np.int64(45)),
#  ('TT_Children_Whose_Birth_Weight_Was_Taken_Urban', np.int64(45)),
#  ('TT_Children_With_Birth_Weight_Less_Than_2_5_Kg_Urban', np.int64(45)),
#  ('UU_Children_Suffering_From_Diarrhoea_Urban', np.int64(45)),
#  ('UU_Children_Suffering_From_Diarrhoea_Who_Received_Haf_Ors_Ort_Urban',
#   np.int64(45)),
#  ('UU_Children_Suffering_From_Acute_Respiratory_Infection_Urban',
#   np.int64(45)),
#  ('UU_Children_Suffering_From_Acute_Respiratory_Infection_Who_Sought_Treatment_Urban',
#   np.int64(45)),
#  ('UU_Children_Suffering_From_Fever_Urban', np.int64(45)),
#  ('UU_Children_Suffering_From_Fever_Who_Sought_Treatment_Urban', np.int64(45)),
#  ('VV_Children_Breastfed_Within_One_Hour_Of_Birth_Urban', np.int64(45)),
#  ('VV_Children_Aged_6_35_Months_Exclusively_Breastfed_For_At_Least_Six_Months_Urban',
#   np.int64(45)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Water_Urban',
#   np.int64(45)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Animal_Formula_Milk_Urban',
#   np.int64(45)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Semi_Solid_Mashed_Food_Urban',
#   np.int64(45)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Solid_Adult_Food_Urban',
#   np.int64(45)),
#  ('VV_Children_Who_Received_Foods_Other_Than_Breast_Milk_During_First_6_Months_Vegetables_Fruits_Urban',
#   np.int64(45)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Water_Urban',
#   np.int64(45)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Animal_Formula_Milk_Urban',
#   np.int64(45)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Semi_Solid_Mashed_Food_Urban',
#   np.int64(45)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Solid_Adult_Food_Urban',
#   np.int64(45)),
#  ('VV_Average_Month_By_Which_Children_Received_Foods_Other_Than_Breast_Milk_Vegetables_Fruits_Urban',
#   np.int64(45)),
#  ('WW_Birth_Registered_Urban', np.int64(45)),
#  ('WW_Children_Whose_Birth_Was_Registered_And_Received_Birth_Certificate_Urban',
#   np.int64(45)),
#  ('XX_Women_Who_Are_Aware_Of_Hiv_Aids_Urban', np.int64(45)),
#  ('XX_Women_Who_Are_Aware_Of_Rti_Sti_Urban', np.int64(45)),
#  ('XX_Women_Who_Are_Aware_Of_Haf_Ors_Ort_Zinc_Urban', np.int64(45)),
#  ('XX_Women_Who_Are_Aware_Of_Danger_Signs_Of_Ari_Pneumonia_Urban',
#   np.int64(45)),
#  ('ZZ_Infant_Mortality_Rate_Urban_Lower_Limit', np.int64(78)),
#  ('ZZ_Infant_Mortality_Rate_Urban_Upper_Limit', np.int64(78)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit', np.int64(78)),
#  ('ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit', np.int64(78)),
#  ('YY_Infant_Mortality_Rate_Imr_Urban_Person', np.int64(92)),
#  ('YY_Infant_Mortality_Rate_Imr_Urban_Male', np.int64(92)),
#  ('YY_Infant_Mortality_Rate_Imr_Urban_Female', np.int64(92)),
#  ('YY_Neo_Natal_Mortality_Rate_Urban', np.int64(92)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Urban_Person', np.int64(92)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Urban_Male', np.int64(92)),
#  ('YY_Under_Five_Mortality_Rate_U5MR_Urban_Female', np.int64(92)),
#  ('YY_Post_Neo_Natal_Mortality_Rate_Urban', np.int64(93)),
#  ('LL_Total_Fertility_Rate_Rural', np.int64(284)),
#  ('LL_Total_Fertility_Rate_Urban', np.int64(284))]

# %%
## Number of features with nulls
len(has_null)
# Out:
# 199
